# %% [markdown]
# Dangers of Walkforward OOS Test Results if there's data leakage.

# %%
import math
import numpy as np
import pandas as pd

# ------------------------------
# Normal CDF (accurate to ~7.5e-8)
# ------------------------------
def normal_cdf(z):
    zz = abs(z)
    pdf = math.exp(-0.5 * zz * zz) / math.sqrt(2.0 * math.pi)
    t = 1.0 / (1.0 + zz * 0.2316419)
    poly = ((((1.330274429 * t - 1.821255978) * t + 1.781477937) * t -
             0.356563782) * t + 0.319381530) * t
    return 1.0 - pdf * poly if z > 0.0 else pdf * poly

# ------------------------------
# Generate a random walk of log prices using NumPy.
# ------------------------------
def generate_random_walk(nprices):
    """
    Generate a random walk of log prices.
    x[0] = 0, then for each step:
      x[i] = x[i-1] + (u1 + u2 - u3 - u4)
    """
    # Generate (nprices-1) x 4 uniform random numbers in [0,1)
    increments = np.random.uniform(0, 1, (nprices - 1, 4))
    deltas = increments[:, 0] + increments[:, 1] - increments[:, 2] - increments[:, 3]
    x = np.empty(nprices)
    x[0] = 0.0
    x[1:] = np.cumsum(deltas)
    return x

# ------------------------------
# Compute dataset: indicator and target
#
# For each valid time index i, compute:
#   - indicator: the weighted linear slope over the window [i-lookback+1, i]
#   - target: price change from x[i] to x[i+lookahead]
# ------------------------------
def compute_dataset(x, lookback, lookahead):
    """
    Returns a pandas DataFrame with columns 'indicator' and 'target'
    computed over a sliding window.
    """
    n = len(x)
    # Valid indices: from (lookback-1) to (n - lookahead - 1)
    indices = np.arange(lookback - 1, n - lookahead)
    # Weights linearly spaced between -1 and 1
    weights = np.linspace(-1, 1, lookback)
    denom = np.sum(weights ** 2)
    
    indicators = []
    targets = []
    for i in indices:
        window = x[i - lookback + 1: i + 1]
        ind = np.dot(weights, window) / denom
        targ = x[i + lookahead] - x[i]
        indicators.append(ind)
        targets.append(targ)
        
    df = pd.DataFrame({'indicator': indicators, 'target': targets})
    return df

# ------------------------------
# Compute regression parameters (beta and constant)
# for a simple linear regression: target ~ indicator.
# ------------------------------
def regression_params(df):
    """
    Given a DataFrame with 'indicator' and 'target' columns,
    compute beta and constant so that:
       prediction = beta * indicator + constant.
    """
    x = df['indicator'].values
    y = df['target'].values
    xmean = np.mean(x)
    ymean = np.mean(y)
    xy = np.sum((x - xmean) * (y - ymean))
    xx = np.sum((x - xmean) ** 2)
    beta = xy / (xx + 1e-60)
    constant = ymean - beta * xmean
    return beta, constant

# ------------------------------
# Walkforward evaluation using pandas and numpy.
# ------------------------------
def walkforward_evaluation(df, ntrain, ntest, omit, extra):
    """
    Splits the dataset into sequential training and test folds.
    For each test case, compute the prediction via regression on the training fold.
    If the prediction is positive, use the target as-is; otherwise, flip its sign.
    Returns an array of out-of-sample (OOS) outcomes.
    """
    trn_ptr = 0
    ncases = len(df)
    oos_values = []
    
    while True:
        test_ptr = trn_ptr + ntrain
        if test_ptr >= ncases:
            break
        
        # Use training data (omit last 'omit' cases, if any)
        train_end = trn_ptr + (ntrain - omit) if (ntrain - omit) > 0 else trn_ptr + ntrain
        train_df = df.iloc[trn_ptr: train_end]
        beta, constant = regression_params(train_df)
        
        # Determine test fold length (could be truncated at the end)
        nt = ntest if test_ptr + ntest <= ncases else ncases - test_ptr
        
        test_df = df.iloc[test_ptr: test_ptr + nt].copy()
        test_df['pred'] = beta * test_df['indicator'] + constant
        # For each test case, use target or its negative based on prediction sign.
        fold_oos = np.where(test_df['pred'] > 0, test_df['target'], -test_df['target'])
        oos_values.extend(fold_oos.tolist())
        
        # Advance pointers for next fold
        trn_ptr += nt + extra
        if trn_ptr >= ncases:
            break
            
    return np.array(oos_values)


# Parameters:
#   nprices   : Total number of prices (bars in history)
#   lookback  : Window length for indicator computation
#   lookahead : Bars into future for target computation
#   ntrain    : Number of cases in training set
#   ntest     : Number of cases in test set
#   omit      : Number of cases to omit from end of training set
#   extra     : Extra bars jumped for the next fold
#   nreps     : Number of replications (forced to be odd)
#
# Returns a dictionary containing:
#   - n_OOS    : Last count of out-of-sample cases
#   - median_t : Median t-score across replications
#   - fraction : Fraction of replications with p-value <= 0.1
#   - t_scores : Array of t-scores from each replication
# ------------------------------
def run_overlap(nprices, lookback, lookahead, ntrain, ntest, omit, extra, nreps):
    # Ensure nreps is odd
    nreps = (nreps // 2) * 2 + 1

    # Check validity of parameters
    if (nprices < lookback + lookahead + ntrain + ntest + 10 or
        nprices < 2 or lookback < 2 or lookahead < 1 or
        ntrain < 2 or ntest < 1 or omit < 0 or extra < 0):
        raise ValueError("Invalid parameters. Ensure nprices >= lookback + lookahead + ntrain + ntest + 10 and other parameters are valid.")
    
    print(f"\nnprices={nprices}  lookback={lookback}  lookahead={lookahead}  ntrain={ntrain}  ntest={ntest}  omit={omit}  extra={extra}")
    
    t_scores = []
    p1_count = 0
    last_oos_count = None
    
    for irep in range(nreps):
        # Generate random walk of log prices.
        x = generate_random_walk(nprices)
        # Build the dataset (indicator and target).
        df = compute_dataset(x, lookback, lookahead)
        # Evaluate out-of-sample (OOS) outcomes.
        oos = walkforward_evaluation(df, ntrain, ntest, omit, extra)
        if len(oos) == 0:
            raise ValueError("No out-of-sample cases computed!")
        
        oos_mean = np.mean(oos)
        oos_std = np.std(oos, ddof=0)
        if oos_std < 1e-20:
            oos_std = 1e-20
        n_OOS = len(oos)
        t_score = math.sqrt(n_OOS) * oos_mean / oos_std
        rtail = 1.0 - normal_cdf(t_score)
        print(f"\nIteration {irep+1}: Mean = {oos_mean:.4f}  StdDev = {oos_std:.4f}  t = {t_score:.4f}  p = {rtail:.4f}")
        t_scores.append(t_score)
        if rtail <= 0.1:
            p1_count += 1
        last_oos_count = n_OOS

    t_scores = np.array(t_scores)
    median_t = np.median(t_scores)
    fraction = p1_count / nreps
    print(f"\nn OOS = {last_oos_count}  Median t = {median_t:.4f}  Fraction with p<= 0.1 = {fraction:.3f}")
    
    # Return the key results as a dictionary.
    return {"n_OOS": last_oos_count, "median_t": median_t, "fraction": fraction, "t_scores": t_scores}

# Example usage in a notebook cell:
# results = run_overlap(nprices=100000, lookback=1000, lookahead=1, ntrain=100, ntest=1, omit=0, extra=0, nreps=51)
# print(results)

# %% [markdown]
# Optimistic Bias from IS/OOS Overlap with Large Test Set

# %%
run_overlap(10000, 20, 5, 50, 50, 0, 0, 1001)
# Out:
# nprices=10000  lookback=20  lookahead=5  ntrain=50  ntest=50  omit=0  extra=0
#
# Iteration 1: Mean = -0.0010  StdDev = 1.2617  t = -0.0762  p = 0.5304
#
# Iteration 2: Mean = 0.0193  StdDev = 1.2963  t = 1.4838  p = 0.0689
#
# Iteration 3: Mean = 0.0264  StdDev = 1.2518  t = 2.0990  p = 0.0179
#
# Iteration 4: Mean = 0.0130  StdDev = 1.2844  t = 1.0088  p = 0.1565
#
# Iteration 5: Mean = 0.0529  StdDev = 1.3103  t = 4.0190  p = 0.0000
#
# Iteration 6: Mean = 0.0016  StdDev = 1.2848  t = 0.1258  p = 0.4499
#
# Iteration 7: Mean = 0.0001  StdDev = 1.2869  t = 0.0115  p = 0.4954
#
# Iteration 8: Mean = 0.0006  StdDev = 1.2967  t = 0.0430  p = 0.4829
#
# Iteration 9: Mean = -0.0238  StdDev = 1.2727  t = -1.8621  p = 0.9687
#
# Iteration 10: Mean = 0.0139  StdDev = 1.2876  t = 1.0794  p = 0.1402
#
# Iteration 11: Mean = 0.0570  StdDev = 1.3059  t = 4.3511  p = 0.0000
#
# Iteration 12: Mean = -0.0082  StdDev = 1.2667  t = -0.6464  p = 0.7410
#
# Iteration 13: Mean = 0.0303  StdDev = 1.3167  t = 2.2919  p = 0.0110
#
# Iteration 14: Mean = -0.0110  StdDev = 1.2688  t = -0.8603  p = 0.8052
#
# Iteration 15: Mean = -0.0032  StdDev = 1.2851  t = -0.2455  p = 0.5970
#
# Iteration 16: Mean = 0.0553  StdDev = 1.2861  t = 4.2806  p = 0.0000
#
# Iteration 17: Mean = 0.0132  StdDev = 1.3098  t = 1.0019  p = 0.1582
#
# Iteration 18: Mean = 0.0110  StdDev = 1.2959  t = 0.8429  p = 0.1996
#
# Iteration 19: Mean = 0.0457  StdDev = 1.3107  t = 3.4722  p = 0.0003
#
# Iteration 20: Mean = -0.0261  StdDev = 1.2945  t = -2.0122  p = 0.9779
#
# Iteration 21: Mean = -0.0078  StdDev = 1.2780  t = -0.6112  p = 0.7295
#
# Iteration 22: Mean = 0.0152  StdDev = 1.2756  t = 1.1898  p = 0.1171
#
# Iteration 23: Mean = 0.0233  StdDev = 1.3066  t = 1.7744  p = 0.0380
#
# Iteration 24: Mean = -0.0013  StdDev = 1.2613  t = -0.1031  p = 0.5411
#
# Iteration 25: Mean = 0.0577  StdDev = 1.2947  t = 4.4393  p = 0.0000
#
# Iteration 26: Mean = 0.0169  StdDev = 1.2918  t = 1.3029  p = 0.0963
#
# Iteration 27: Mean = -0.0011  StdDev = 1.3010  t = -0.0806  p = 0.5321
#
# Iteration 28: Mean = -0.0075  StdDev = 1.2735  t = -0.5878  p = 0.7217
#
# Iteration 29: Mean = 0.0607  StdDev = 1.2455  t = 4.8556  p = 0.0000
#
# Iteration 30: Mean = 0.0450  StdDev = 1.2884  t = 3.4783  p = 0.0003
#
# Iteration 31: Mean = 0.0216  StdDev = 1.2900  t = 1.6661  p = 0.0479
#
# Iteration 32: Mean = 0.0205  StdDev = 1.2473  t = 1.6355  p = 0.0510
#
# Iteration 33: Mean = -0.0135  StdDev = 1.2557  t = -1.0733  p = 0.8584
#
# Iteration 34: Mean = -0.0071  StdDev = 1.3105  t = -0.5417  p = 0.7060
#
# Iteration 35: Mean = 0.0029  StdDev = 1.2943  t = 0.2257  p = 0.4107
#
# Iteration 36: Mean = -0.0173  StdDev = 1.2775  t = -1.3518  p = 0.9118
#
# Iteration 37: Mean = 0.0459  StdDev = 1.2808  t = 3.5698  p = 0.0002
#
# Iteration 38: Mean = -0.0081  StdDev = 1.2979  t = -0.6217  p = 0.7329
#
# Iteration 39: Mean = 0.0142  StdDev = 1.2992  t = 1.0859  p = 0.1388
#
# Iteration 40: Mean = -0.0296  StdDev = 1.3080  t = -2.2565  p = 0.9880
#
# Iteration 41: Mean = 0.0071  StdDev = 1.2929  t = 0.5482  p = 0.2918
#
# Iteration 42: Mean = 0.0629  StdDev = 1.2834  t = 4.8843  p = 0.0000
#
# Iteration 43: Mean = 0.0065  StdDev = 1.2686  t = 0.5106  p = 0.3048
#
# Iteration 44: Mean = -0.0019  StdDev = 1.3085  t = -0.1483  p = 0.5589
#
# Iteration 45: Mean = 0.0521  StdDev = 1.2736  t = 4.0792  p = 0.0000
#
# Iteration 46: Mean = -0.0802  StdDev = 1.2622  t = -6.3294  p = 1.0000
#
# Iteration 47: Mean = 0.0019  StdDev = 1.2496  t = 0.1488  p = 0.4409
#
# Iteration 48: Mean = 0.0395  StdDev = 1.3219  t = 2.9745  p = 0.0015
#
# Iteration 49: Mean = -0.0258  StdDev = 1.2750  t = -2.0194  p = 0.9783
#
# Iteration 50: Mean = -0.0089  StdDev = 1.2926  t = -0.6881  p = 0.7543
#
# Iteration 51: Mean = 0.0239  StdDev = 1.3092  t = 1.8218  p = 0.0342
#
# Iteration 52: Mean = 0.0283  StdDev = 1.2788  t = 2.2078  p = 0.0136
#
# Iteration 53: Mean = 0.0117  StdDev = 1.2933  t = 0.9031  p = 0.1832
#
# Iteration 54: Mean = 0.0336  StdDev = 1.2796  t = 2.6190  p = 0.0044
#
# Iteration 55: Mean = 0.0151  StdDev = 1.2707  t = 1.1839  p = 0.1182
#
# Iteration 56: Mean = -0.0251  StdDev = 1.3152  t = -1.8992  p = 0.9712
#
# Iteration 57: Mean = -0.0128  StdDev = 1.2876  t = -0.9876  p = 0.8383
#
# Iteration 58: Mean = 0.0579  StdDev = 1.3202  t = 4.3665  p = 0.0000
#
# Iteration 59: Mean = 0.0108  StdDev = 1.3030  t = 0.8233  p = 0.2052
#
# Iteration 60: Mean = 0.0016  StdDev = 1.2913  t = 0.1224  p = 0.4513
#
# Iteration 61: Mean = 0.0466  StdDev = 1.2947  t = 3.5861  p = 0.0002
#
# Iteration 62: Mean = 0.0266  StdDev = 1.2634  t = 2.0963  p = 0.0180
#
# Iteration 63: Mean = -0.0028  StdDev = 1.3013  t = -0.2122  p = 0.5840
#
# Iteration 64: Mean = -0.0373  StdDev = 1.3208  t = -2.8170  p = 0.9976
#
# Iteration 65: Mean = 0.0372  StdDev = 1.2947  t = 2.8614  p = 0.0021
#
# Iteration 66: Mean = -0.0416  StdDev = 1.2822  t = -3.2363  p = 0.9994
#
# Iteration 67: Mean = -0.0446  StdDev = 1.2865  t = -3.4514  p = 0.9997
#
# Iteration 68: Mean = 0.0211  StdDev = 1.3052  t = 1.6087  p = 0.0538
#
# Iteration 69: Mean = 0.0746  StdDev = 1.2899  t = 5.7588  p = 0.0000
#
# Iteration 70: Mean = 0.0209  StdDev = 1.3009  t = 1.6010  p = 0.0547
#
# Iteration 71: Mean = 0.0273  StdDev = 1.2928  t = 2.1007  p = 0.0178
#
# Iteration 72: Mean = -0.0070  StdDev = 1.2969  t = -0.5405  p = 0.7056
#
# Iteration 73: Mean = 0.0379  StdDev = 1.2958  t = 2.9143  p = 0.0018
#
# Iteration 74: Mean = -0.0095  StdDev = 1.2781  t = -0.7426  p = 0.7711
#
# Iteration 75: Mean = -0.0007  StdDev = 1.2829  t = -0.0558  p = 0.5222
#
# Iteration 76: Mean = 0.0509  StdDev = 1.2735  t = 3.9835  p = 0.0000
#
# Iteration 77: Mean = 0.0195  StdDev = 1.2762  t = 1.5207  p = 0.0642
#
# Iteration 78: Mean = 0.0316  StdDev = 1.2740  t = 2.4696  p = 0.0068
#
# Iteration 79: Mean = 0.0148  StdDev = 1.2581  t = 1.1747  p = 0.1201
#
# Iteration 80: Mean = -0.0027  StdDev = 1.2741  t = -0.2119  p = 0.5839
#
# Iteration 81: Mean = 0.0278  StdDev = 1.3295  t = 2.0839  p = 0.0186
#
# Iteration 82: Mean = -0.0220  StdDev = 1.2899  t = -1.7027  p = 0.9557
#
# Iteration 83: Mean = -0.0239  StdDev = 1.3416  t = -1.7756  p = 0.9621
#
# Iteration 84: Mean = 0.0323  StdDev = 1.3065  t = 2.4622  p = 0.0069
#
# Iteration 85: Mean = -0.0074  StdDev = 1.2727  t = -0.5806  p = 0.7192
#
# Iteration 86: Mean = -0.0169  StdDev = 1.2703  t = -1.3228  p = 0.9071
#
# Iteration 87: Mean = 0.0188  StdDev = 1.2880  t = 1.4552  p = 0.0728
#
# Iteration 88: Mean = 0.0138  StdDev = 1.3029  t = 1.0589  p = 0.1448
#
# Iteration 89: Mean = -0.0424  StdDev = 1.3029  t = -3.2423  p = 0.9994
#
# Iteration 90: Mean = -0.0305  StdDev = 1.2842  t = -2.3630  p = 0.9909
#
# Iteration 91: Mean = -0.0087  StdDev = 1.2882  t = -0.6735  p = 0.7497
#
# Iteration 92: Mean = 0.0281  StdDev = 1.3243  t = 2.1132  p = 0.0173
#
# Iteration 93: Mean = -0.0202  StdDev = 1.2790  t = -1.5744  p = 0.9423
#
# Iteration 94: Mean = 0.0215  StdDev = 1.2855  t = 1.6690  p = 0.0476
#
# Iteration 95: Mean = -0.0195  StdDev = 1.2708  t = -1.5290  p = 0.9369
#
# Iteration 96: Mean = -0.0300  StdDev = 1.2785  t = -2.3406  p = 0.9904
#
# Iteration 97: Mean = 0.0404  StdDev = 1.3026  t = 3.0869  p = 0.0010
#
# Iteration 98: Mean = 0.0065  StdDev = 1.2914  t = 0.4982  p = 0.3092
#
# Iteration 99: Mean = 0.0437  StdDev = 1.2866  t = 3.3868  p = 0.0004
#
# Iteration 100: Mean = 0.0155  StdDev = 1.2818  t = 1.2074  p = 0.1136
#
# Iteration 101: Mean = 0.0424  StdDev = 1.2824  t = 3.2968  p = 0.0005
#
# Iteration 102: Mean = 0.0047  StdDev = 1.3025  t = 0.3563  p = 0.3608
#
# Iteration 103: Mean = 0.0176  StdDev = 1.2797  t = 1.3736  p = 0.0848
#
# Iteration 104: Mean = -0.0389  StdDev = 1.2898  t = -3.0019  p = 0.9987
#
# Iteration 105: Mean = 0.0394  StdDev = 1.3062  t = 3.0043  p = 0.0013
#
# Iteration 106: Mean = 0.0537  StdDev = 1.2647  t = 4.2300  p = 0.0000
#
# Iteration 107: Mean = 0.0186  StdDev = 1.2676  t = 1.4582  p = 0.0724
#
# Iteration 108: Mean = 0.0415  StdDev = 1.2945  t = 3.1933  p = 0.0007
#
# Iteration 109: Mean = 0.0105  StdDev = 1.3026  t = 0.8018  p = 0.2113
#
# Iteration 110: Mean = 0.0234  StdDev = 1.2231  t = 1.9071  p = 0.0283
#
# Iteration 111: Mean = 0.0096  StdDev = 1.2993  t = 0.7368  p = 0.2306
#
# Iteration 112: Mean = -0.0191  StdDev = 1.2745  t = -1.4968  p = 0.9328
#
# Iteration 113: Mean = 0.0094  StdDev = 1.3073  t = 0.7141  p = 0.2376
#
# Iteration 114: Mean = 0.0113  StdDev = 1.3151  t = 0.8531  p = 0.1968
#
# Iteration 115: Mean = 0.0361  StdDev = 1.2972  t = 2.7755  p = 0.0028
#
# Iteration 116: Mean = 0.0114  StdDev = 1.3016  t = 0.8746  p = 0.1909
#
# Iteration 117: Mean = 0.0654  StdDev = 1.2839  t = 5.0776  p = 0.0000
#
# Iteration 118: Mean = 0.0059  StdDev = 1.2978  t = 0.4564  p = 0.3241
#
# Iteration 119: Mean = 0.0296  StdDev = 1.2819  t = 2.2987  p = 0.0108
#
# Iteration 120: Mean = 0.0631  StdDev = 1.2934  t = 4.8638  p = 0.0000
#
# Iteration 121: Mean = 0.0456  StdDev = 1.3031  t = 3.4876  p = 0.0002
#
# Iteration 122: Mean = 0.0247  StdDev = 1.2853  t = 1.9160  p = 0.0277
#
# Iteration 123: Mean = 0.0104  StdDev = 1.2892  t = 0.8017  p = 0.2114
#
# Iteration 124: Mean = 0.0183  StdDev = 1.3060  t = 1.3925  p = 0.0819
#
# Iteration 125: Mean = 0.0041  StdDev = 1.3069  t = 0.3142  p = 0.3767
#
# Iteration 126: Mean = -0.0013  StdDev = 1.3168  t = -0.1002  p = 0.5399
#
# Iteration 127: Mean = 0.0158  StdDev = 1.2800  t = 1.2287  p = 0.1096
#
# Iteration 128: Mean = 0.0049  StdDev = 1.3123  t = 0.3753  p = 0.3537
#
# Iteration 129: Mean = -0.0065  StdDev = 1.2966  t = -0.4990  p = 0.6911
#
# Iteration 130: Mean = 0.0325  StdDev = 1.2521  t = 2.5886  p = 0.0048
#
# Iteration 131: Mean = -0.0181  StdDev = 1.3078  t = -1.3803  p = 0.9163
#
# Iteration 132: Mean = 0.0440  StdDev = 1.2651  t = 3.4653  p = 0.0003
#
# Iteration 133: Mean = 0.0530  StdDev = 1.3027  t = 4.0554  p = 0.0000
#
# Iteration 134: Mean = -0.0437  StdDev = 1.2868  t = -3.3798  p = 0.9996
#
# Iteration 135: Mean = 0.0014  StdDev = 1.3138  t = 0.1036  p = 0.4588
#
# Iteration 136: Mean = 0.0356  StdDev = 1.2691  t = 2.7931  p = 0.0026
#
# Iteration 137: Mean = -0.0145  StdDev = 1.3068  t = -1.1027  p = 0.8649
#
# Iteration 138: Mean = 0.0255  StdDev = 1.2865  t = 1.9776  p = 0.0240
#
# Iteration 139: Mean = 0.0018  StdDev = 1.2856  t = 0.1360  p = 0.4459
#
# Iteration 140: Mean = -0.0217  StdDev = 1.2784  t = -1.6948  p = 0.9549
#
# Iteration 141: Mean = -0.0066  StdDev = 1.3179  t = -0.4975  p = 0.6906
#
# Iteration 142: Mean = 0.0256  StdDev = 1.2990  t = 1.9610  p = 0.0249
#
# Iteration 143: Mean = 0.0089  StdDev = 1.3008  t = 0.6809  p = 0.2480
#
# Iteration 144: Mean = 0.0241  StdDev = 1.2979  t = 1.8483  p = 0.0323
#
# Iteration 145: Mean = -0.0039  StdDev = 1.3044  t = -0.2980  p = 0.6171
#
# Iteration 146: Mean = 0.0536  StdDev = 1.3138  t = 4.0672  p = 0.0000
#
# Iteration 147: Mean = -0.0053  StdDev = 1.2774  t = -0.4110  p = 0.6595
#
# Iteration 148: Mean = -0.0364  StdDev = 1.2833  t = -2.8262  p = 0.9976
#
# Iteration 149: Mean = -0.0498  StdDev = 1.2795  t = -3.8742  p = 0.9999
#
# Iteration 150: Mean = 0.0237  StdDev = 1.2877  t = 1.8328  p = 0.0334
#
# Iteration 151: Mean = -0.0070  StdDev = 1.2856  t = -0.5441  p = 0.7068
#
# Iteration 152: Mean = -0.0182  StdDev = 1.3185  t = -1.3777  p = 0.9158
#
# Iteration 153: Mean = 0.0341  StdDev = 1.2939  t = 2.6281  p = 0.0043
#
# Iteration 154: Mean = 0.0762  StdDev = 1.3125  t = 5.7831  p = 0.0000
#
# Iteration 155: Mean = 0.0304  StdDev = 1.2665  t = 2.3928  p = 0.0084
#
# Iteration 156: Mean = 0.0044  StdDev = 1.2748  t = 0.3409  p = 0.3666
#
# Iteration 157: Mean = -0.0264  StdDev = 1.3090  t = -2.0077  p = 0.9777
#
# Iteration 158: Mean = 0.0233  StdDev = 1.2883  t = 1.8038  p = 0.0356
#
# Iteration 159: Mean = 0.0247  StdDev = 1.3053  t = 1.8827  p = 0.0299
#
# Iteration 160: Mean = 0.0464  StdDev = 1.2947  t = 3.5742  p = 0.0002
#
# Iteration 161: Mean = 0.0208  StdDev = 1.2945  t = 1.6044  p = 0.0543
#
# Iteration 162: Mean = -0.0157  StdDev = 1.2863  t = -1.2123  p = 0.8873
#
# Iteration 163: Mean = 0.0266  StdDev = 1.3339  t = 1.9866  p = 0.0235
#
# Iteration 164: Mean = -0.0379  StdDev = 1.2704  t = -2.9707  p = 0.9985
#
# Iteration 165: Mean = -0.0089  StdDev = 1.2798  t = -0.6944  p = 0.7563
#
# Iteration 166: Mean = 0.0422  StdDev = 1.2953  t = 3.2451  p = 0.0006
#
# Iteration 167: Mean = 0.0236  StdDev = 1.2902  t = 1.8230  p = 0.0342
#
# Iteration 168: Mean = -0.0397  StdDev = 1.2901  t = -3.0679  p = 0.9989
#
# Iteration 169: Mean = -0.0021  StdDev = 1.3082  t = -0.1594  p = 0.5633
#
# Iteration 170: Mean = -0.0276  StdDev = 1.3113  t = -2.0983  p = 0.9821
#
# Iteration 171: Mean = 0.0051  StdDev = 1.2776  t = 0.3992  p = 0.3449
#
# Iteration 172: Mean = 0.0002  StdDev = 1.2899  t = 0.0140  p = 0.4944
#
# Iteration 173: Mean = 0.0283  StdDev = 1.2589  t = 2.2417  p = 0.0125
#
# Iteration 174: Mean = -0.0323  StdDev = 1.2935  t = -2.4863  p = 0.9935
#
# Iteration 175: Mean = -0.0207  StdDev = 1.2928  t = -1.5927  p = 0.9444
#
# Iteration 176: Mean = -0.0438  StdDev = 1.3076  t = -3.3367  p = 0.9996
#
# Iteration 177: Mean = -0.0122  StdDev = 1.2843  t = -0.9435  p = 0.8273
#
# Iteration 178: Mean = 0.0057  StdDev = 1.3102  t = 0.4321  p = 0.3328
#
# Iteration 179: Mean = -0.0442  StdDev = 1.2895  t = -3.4157  p = 0.9997
#
# Iteration 180: Mean = -0.0278  StdDev = 1.2744  t = -2.1714  p = 0.9850
#
# Iteration 181: Mean = 0.0280  StdDev = 1.2909  t = 2.1615  p = 0.0153
#
# Iteration 182: Mean = 0.0163  StdDev = 1.2952  t = 1.2500  p = 0.1056
#
# Iteration 183: Mean = -0.0183  StdDev = 1.3082  t = -1.3910  p = 0.9179
#
# Iteration 184: Mean = 0.0087  StdDev = 1.2745  t = 0.6827  p = 0.2474
#
# Iteration 185: Mean = 0.0328  StdDev = 1.3043  t = 2.5021  p = 0.0062
#
# Iteration 186: Mean = -0.0054  StdDev = 1.2847  t = -0.4203  p = 0.6629
#
# Iteration 187: Mean = 0.0261  StdDev = 1.2862  t = 2.0191  p = 0.0217
#
# Iteration 188: Mean = -0.0410  StdDev = 1.3332  t = -3.0659  p = 0.9989
#
# Iteration 189: Mean = 0.0155  StdDev = 1.2594  t = 1.2281  p = 0.1097
#
# Iteration 190: Mean = -0.0019  StdDev = 1.3005  t = -0.1487  p = 0.5591
#
# Iteration 191: Mean = 0.0267  StdDev = 1.2690  t = 2.1002  p = 0.0179
#
# Iteration 192: Mean = 0.0342  StdDev = 1.2915  t = 2.6417  p = 0.0041
#
# Iteration 193: Mean = 0.0133  StdDev = 1.2792  t = 1.0343  p = 0.1505
#
# Iteration 194: Mean = -0.0082  StdDev = 1.2683  t = -0.6451  p = 0.7406
#
# Iteration 195: Mean = 0.0221  StdDev = 1.2981  t = 1.6965  p = 0.0449
#
# Iteration 196: Mean = 0.0379  StdDev = 1.2936  t = 2.9157  p = 0.0018
#
# Iteration 197: Mean = -0.0034  StdDev = 1.2843  t = -0.2624  p = 0.6035
#
# Iteration 198: Mean = 0.0302  StdDev = 1.3141  t = 2.2904  p = 0.0110
#
# Iteration 199: Mean = 0.0052  StdDev = 1.3110  t = 0.3983  p = 0.3452
#
# Iteration 200: Mean = 0.0596  StdDev = 1.2882  t = 4.6130  p = 0.0000
#
# Iteration 201: Mean = 0.0111  StdDev = 1.3170  t = 0.8373  p = 0.2012
#
# Iteration 202: Mean = -0.0465  StdDev = 1.2828  t = -3.6079  p = 0.9998
#
# Iteration 203: Mean = -0.0140  StdDev = 1.2926  t = -1.0790  p = 0.8597
#
# Iteration 204: Mean = -0.0302  StdDev = 1.3037  t = -2.3085  p = 0.9895
#
# Iteration 205: Mean = -0.0120  StdDev = 1.2867  t = -0.9288  p = 0.8235
#
# Iteration 206: Mean = 0.0039  StdDev = 1.2906  t = 0.2978  p = 0.3829
#
# Iteration 207: Mean = -0.0155  StdDev = 1.3184  t = -1.1733  p = 0.8797
#
# Iteration 208: Mean = 0.0355  StdDev = 1.2984  t = 2.7243  p = 0.0032
#
# Iteration 209: Mean = 0.0448  StdDev = 1.2697  t = 3.5165  p = 0.0002
#
# Iteration 210: Mean = 0.0022  StdDev = 1.3115  t = 0.1646  p = 0.4346
#
# Iteration 211: Mean = 0.0288  StdDev = 1.3007  t = 2.2057  p = 0.0137
#
# Iteration 212: Mean = 0.0477  StdDev = 1.2791  t = 3.7181  p = 0.0001
#
# Iteration 213: Mean = 0.0263  StdDev = 1.2687  t = 2.0627  p = 0.0196
#
# Iteration 214: Mean = -0.0269  StdDev = 1.3076  t = -2.0513  p = 0.9799
#
# Iteration 215: Mean = -0.0215  StdDev = 1.3043  t = -1.6416  p = 0.9497
#
# Iteration 216: Mean = 0.0283  StdDev = 1.2754  t = 2.2072  p = 0.0137
#
# Iteration 217: Mean = -0.0085  StdDev = 1.3083  t = -0.6495  p = 0.7420
#
# Iteration 218: Mean = 0.0081  StdDev = 1.2680  t = 0.6348  p = 0.2628
#
# Iteration 219: Mean = 0.0381  StdDev = 1.2961  t = 2.9324  p = 0.0017
#
# Iteration 220: Mean = 0.0243  StdDev = 1.2940  t = 1.8696  p = 0.0308
#
# Iteration 221: Mean = 0.0153  StdDev = 1.3085  t = 1.1668  p = 0.1217
#
# Iteration 222: Mean = 0.0049  StdDev = 1.3058  t = 0.3760  p = 0.3535
#
# Iteration 223: Mean = -0.0513  StdDev = 1.2722  t = -4.0197  p = 1.0000
#
# Iteration 224: Mean = 0.0256  StdDev = 1.3235  t = 1.9286  p = 0.0269
#
# Iteration 225: Mean = 0.0023  StdDev = 1.2886  t = 0.1803  p = 0.4284
#
# Iteration 226: Mean = 0.0414  StdDev = 1.3003  t = 3.1749  p = 0.0007
#
# Iteration 227: Mean = 0.0118  StdDev = 1.2674  t = 0.9255  p = 0.1774
#
# Iteration 228: Mean = -0.0046  StdDev = 1.3028  t = -0.3530  p = 0.6379
#
# Iteration 229: Mean = -0.0252  StdDev = 1.2648  t = -1.9866  p = 0.9765
#
# Iteration 230: Mean = -0.0191  StdDev = 1.2903  t = -1.4720  p = 0.9295
#
# Iteration 231: Mean = -0.0216  StdDev = 1.2899  t = -1.6662  p = 0.9522
#
# Iteration 232: Mean = -0.0054  StdDev = 1.2876  t = -0.4207  p = 0.6630
#
# Iteration 233: Mean = 0.0124  StdDev = 1.2966  t = 0.9537  p = 0.1701
#
# Iteration 234: Mean = 0.0346  StdDev = 1.2825  t = 2.6857  p = 0.0036
#
# Iteration 235: Mean = 0.0032  StdDev = 1.2792  t = 0.2509  p = 0.4009
#
# Iteration 236: Mean = 0.0006  StdDev = 1.2910  t = 0.0463  p = 0.4815
#
# Iteration 237: Mean = -0.0014  StdDev = 1.2832  t = -0.1088  p = 0.5433
#
# Iteration 238: Mean = -0.0228  StdDev = 1.2775  t = -1.7744  p = 0.9620
#
# Iteration 239: Mean = -0.0283  StdDev = 1.2745  t = -2.2110  p = 0.9865
#
# Iteration 240: Mean = 0.0298  StdDev = 1.2854  t = 2.3091  p = 0.0105
#
# Iteration 241: Mean = 0.0160  StdDev = 1.2908  t = 1.2332  p = 0.1087
#
# Iteration 242: Mean = -0.0184  StdDev = 1.2712  t = -1.4392  p = 0.9249
#
# Iteration 243: Mean = -0.0247  StdDev = 1.2775  t = -1.9274  p = 0.9730
#
# Iteration 244: Mean = 0.0180  StdDev = 1.2802  t = 1.4023  p = 0.0804
#
# Iteration 245: Mean = 0.0226  StdDev = 1.2873  t = 1.7501  p = 0.0400
#
# Iteration 246: Mean = -0.0066  StdDev = 1.2972  t = -0.5051  p = 0.6933
#
# Iteration 247: Mean = -0.0087  StdDev = 1.3164  t = -0.6586  p = 0.7449
#
# Iteration 248: Mean = 0.0081  StdDev = 1.2628  t = 0.6395  p = 0.2612
#
# Iteration 249: Mean = 0.0462  StdDev = 1.2865  t = 3.5779  p = 0.0002
#
# Iteration 250: Mean = 0.0694  StdDev = 1.2912  t = 5.3572  p = 0.0000
#
# Iteration 251: Mean = 0.0166  StdDev = 1.3042  t = 1.2649  p = 0.1030
#
# Iteration 252: Mean = 0.0093  StdDev = 1.3054  t = 0.7087  p = 0.2393
#
# Iteration 253: Mean = 0.0466  StdDev = 1.2705  t = 3.6510  p = 0.0001
#
# Iteration 254: Mean = 0.0366  StdDev = 1.3196  t = 2.7621  p = 0.0029
#
# Iteration 255: Mean = 0.0278  StdDev = 1.2864  t = 2.1541  p = 0.0156
#
# Iteration 256: Mean = -0.0086  StdDev = 1.2572  t = -0.6848  p = 0.7533
#
# Iteration 257: Mean = -0.0189  StdDev = 1.2939  t = -1.4528  p = 0.9269
#
# Iteration 258: Mean = 0.0371  StdDev = 1.2851  t = 2.8760  p = 0.0020
#
# Iteration 259: Mean = 0.0072  StdDev = 1.2984  t = 0.5499  p = 0.2912
#
# Iteration 260: Mean = -0.0016  StdDev = 1.2787  t = -0.1208  p = 0.5481
#
# Iteration 261: Mean = 0.0395  StdDev = 1.2823  t = 3.0709  p = 0.0011
#
# Iteration 262: Mean = -0.0049  StdDev = 1.3154  t = -0.3704  p = 0.6444
#
# Iteration 263: Mean = 0.0083  StdDev = 1.2808  t = 0.6435  p = 0.2600
#
# Iteration 264: Mean = -0.0216  StdDev = 1.2621  t = -1.7028  p = 0.9557
#
# Iteration 265: Mean = 0.0172  StdDev = 1.2983  t = 1.3232  p = 0.0929
#
# Iteration 266: Mean = -0.0782  StdDev = 1.2950  t = -6.0183  p = 1.0000
#
# Iteration 267: Mean = -0.0233  StdDev = 1.2604  t = -1.8391  p = 0.9671
#
# Iteration 268: Mean = 0.0012  StdDev = 1.3269  t = 0.0935  p = 0.4627
#
# Iteration 269: Mean = 0.0176  StdDev = 1.2903  t = 1.3620  p = 0.0866
#
# Iteration 270: Mean = 0.0149  StdDev = 1.2883  t = 1.1550  p = 0.1240
#
# Iteration 271: Mean = 0.0222  StdDev = 1.2864  t = 1.7181  p = 0.0429
#
# Iteration 272: Mean = -0.0011  StdDev = 1.2941  t = -0.0816  p = 0.5325
#
# Iteration 273: Mean = 0.0406  StdDev = 1.3036  t = 3.1065  p = 0.0009
#
# Iteration 274: Mean = 0.0064  StdDev = 1.3193  t = 0.4869  p = 0.3132
#
# Iteration 275: Mean = 0.0421  StdDev = 1.2865  t = 3.2565  p = 0.0006
#
# Iteration 276: Mean = 0.0090  StdDev = 1.2991  t = 0.6916  p = 0.2446
#
# Iteration 277: Mean = -0.0601  StdDev = 1.2926  t = -4.6311  p = 1.0000
#
# Iteration 278: Mean = 0.0065  StdDev = 1.3091  t = 0.4926  p = 0.3111
#
# Iteration 279: Mean = -0.0048  StdDev = 1.2864  t = -0.3710  p = 0.6447
#
# Iteration 280: Mean = 0.0447  StdDev = 1.2929  t = 3.4418  p = 0.0003
#
# Iteration 281: Mean = 0.0020  StdDev = 1.2739  t = 0.1588  p = 0.4369
#
# Iteration 282: Mean = -0.0376  StdDev = 1.3122  t = -2.8524  p = 0.9978
#
# Iteration 283: Mean = -0.0229  StdDev = 1.3138  t = -1.7348  p = 0.9586
#
# Iteration 284: Mean = 0.0290  StdDev = 1.2690  t = 2.2779  p = 0.0114
#
# Iteration 285: Mean = -0.0382  StdDev = 1.2745  t = -2.9834  p = 0.9986
#
# Iteration 286: Mean = 0.0249  StdDev = 1.2953  t = 1.9145  p = 0.0278
#
# Iteration 287: Mean = -0.0212  StdDev = 1.3053  t = -1.6202  p = 0.9474
#
# Iteration 288: Mean = 0.0256  StdDev = 1.2852  t = 1.9814  p = 0.0238
#
# Iteration 289: Mean = 0.0121  StdDev = 1.2930  t = 0.9292  p = 0.1764
#
# Iteration 290: Mean = 0.0051  StdDev = 1.2995  t = 0.3874  p = 0.3492
#
# Iteration 291: Mean = -0.0466  StdDev = 1.2974  t = -3.5805  p = 0.9998
#
# Iteration 292: Mean = 0.0010  StdDev = 1.2904  t = 0.0798  p = 0.4682
#
# Iteration 293: Mean = 0.0210  StdDev = 1.3066  t = 1.6039  p = 0.0544
#
# Iteration 294: Mean = 0.0137  StdDev = 1.2885  t = 1.0573  p = 0.1452
#
# Iteration 295: Mean = 0.0078  StdDev = 1.2997  t = 0.5989  p = 0.2746
#
# Iteration 296: Mean = -0.0226  StdDev = 1.2686  t = -1.7756  p = 0.9621
#
# Iteration 297: Mean = -0.0039  StdDev = 1.2816  t = -0.3059  p = 0.6202
#
# Iteration 298: Mean = 0.0104  StdDev = 1.2868  t = 0.8022  p = 0.2112
#
# Iteration 299: Mean = 0.0572  StdDev = 1.2998  t = 4.3825  p = 0.0000
#
# Iteration 300: Mean = -0.0161  StdDev = 1.2918  t = -1.2408  p = 0.8927
#
# Iteration 301: Mean = 0.0630  StdDev = 1.2997  t = 4.8302  p = 0.0000
#
# Iteration 302: Mean = 0.0011  StdDev = 1.3134  t = 0.0799  p = 0.4682
#
# Iteration 303: Mean = 0.0091  StdDev = 1.2662  t = 0.7143  p = 0.2375
#
# Iteration 304: Mean = -0.0321  StdDev = 1.3166  t = -2.4264  p = 0.9924
#
# Iteration 305: Mean = -0.0234  StdDev = 1.2928  t = -1.7997  p = 0.9640
#
# Iteration 306: Mean = -0.0006  StdDev = 1.3016  t = -0.0433  p = 0.5173
#
# Iteration 307: Mean = 0.0140  StdDev = 1.2969  t = 1.0786  p = 0.1404
#
# Iteration 308: Mean = -0.0035  StdDev = 1.3022  t = -0.2710  p = 0.6068
#
# Iteration 309: Mean = 0.0663  StdDev = 1.2775  t = 5.1743  p = 0.0000
#
# Iteration 310: Mean = 0.0416  StdDev = 1.2998  t = 3.1894  p = 0.0007
#
# Iteration 311: Mean = 0.0147  StdDev = 1.2629  t = 1.1570  p = 0.1236
#
# Iteration 312: Mean = 0.0068  StdDev = 1.2926  t = 0.5232  p = 0.3004
#
# Iteration 313: Mean = -0.0009  StdDev = 1.2667  t = -0.0745  p = 0.5297
#
# Iteration 314: Mean = 0.0109  StdDev = 1.2865  t = 0.8469  p = 0.1985
#
# Iteration 315: Mean = -0.0151  StdDev = 1.2936  t = -1.1622  p = 0.8774
#
# Iteration 316: Mean = 0.0227  StdDev = 1.2801  t = 1.7666  p = 0.0386
#
# Iteration 317: Mean = -0.0113  StdDev = 1.2893  t = -0.8745  p = 0.8091
#
# Iteration 318: Mean = 0.0139  StdDev = 1.3131  t = 1.0583  p = 0.1450
#
# Iteration 319: Mean = -0.0083  StdDev = 1.2693  t = -0.6489  p = 0.7418
#
# Iteration 320: Mean = 0.0242  StdDev = 1.2928  t = 1.8662  p = 0.0310
#
# Iteration 321: Mean = -0.0231  StdDev = 1.2902  t = -1.7827  p = 0.9627
#
# Iteration 322: Mean = -0.0145  StdDev = 1.3138  t = -1.1029  p = 0.8650
#
# Iteration 323: Mean = -0.0510  StdDev = 1.2839  t = -3.9613  p = 1.0000
#
# Iteration 324: Mean = -0.0113  StdDev = 1.3000  t = -0.8679  p = 0.8073
#
# Iteration 325: Mean = 0.0537  StdDev = 1.3015  t = 4.1087  p = 0.0000
#
# Iteration 326: Mean = 0.0100  StdDev = 1.2826  t = 0.7785  p = 0.2181
#
# Iteration 327: Mean = -0.0271  StdDev = 1.2778  t = -2.1113  p = 0.9826
#
# Iteration 328: Mean = 0.0337  StdDev = 1.2920  t = 2.6003  p = 0.0047
#
# Iteration 329: Mean = -0.0194  StdDev = 1.2890  t = -1.4961  p = 0.9327
#
# Iteration 330: Mean = -0.0454  StdDev = 1.3074  t = -3.4585  p = 0.9997
#
# Iteration 331: Mean = -0.0417  StdDev = 1.3104  t = -3.1738  p = 0.9992
#
# Iteration 332: Mean = 0.0251  StdDev = 1.2773  t = 1.9586  p = 0.0251
#
# Iteration 333: Mean = 0.0382  StdDev = 1.3074  t = 2.9130  p = 0.0018
#
# Iteration 334: Mean = 0.0512  StdDev = 1.3005  t = 3.9238  p = 0.0000
#
# Iteration 335: Mean = 0.0342  StdDev = 1.2609  t = 2.6989  p = 0.0035
#
# Iteration 336: Mean = 0.0448  StdDev = 1.3005  t = 3.4287  p = 0.0003
#
# Iteration 337: Mean = -0.0216  StdDev = 1.2712  t = -1.6943  p = 0.9549
#
# Iteration 338: Mean = 0.0119  StdDev = 1.2759  t = 0.9292  p = 0.1764
#
# Iteration 339: Mean = -0.0211  StdDev = 1.2861  t = -1.6338  p = 0.9489
#
# Iteration 340: Mean = 0.0346  StdDev = 1.2719  t = 2.7112  p = 0.0034
#
# Iteration 341: Mean = 0.0504  StdDev = 1.2992  t = 3.8619  p = 0.0001
#
# Iteration 342: Mean = 0.0127  StdDev = 1.2816  t = 0.9892  p = 0.1613
#
# Iteration 343: Mean = -0.0056  StdDev = 1.2965  t = -0.4291  p = 0.6661
#
# Iteration 344: Mean = -0.0071  StdDev = 1.3028  t = -0.5468  p = 0.7077
#
# Iteration 345: Mean = 0.0082  StdDev = 1.3087  t = 0.6275  p = 0.2652
#
# Iteration 346: Mean = -0.0131  StdDev = 1.2886  t = -1.0106  p = 0.8439
#
# Iteration 347: Mean = -0.0468  StdDev = 1.2992  t = -3.5876  p = 0.9998
#
# Iteration 348: Mean = -0.0038  StdDev = 1.2884  t = -0.2919  p = 0.6148
#
# Iteration 349: Mean = 0.0053  StdDev = 1.2709  t = 0.4194  p = 0.3375
#
# Iteration 350: Mean = -0.0122  StdDev = 1.2686  t = -0.9593  p = 0.8313
#
# Iteration 351: Mean = -0.0215  StdDev = 1.2774  t = -1.6777  p = 0.9533
#
# Iteration 352: Mean = -0.0560  StdDev = 1.3062  t = -4.2682  p = 1.0000
#
# Iteration 353: Mean = 0.0144  StdDev = 1.2977  t = 1.1049  p = 0.1346
#
# Iteration 354: Mean = 0.0126  StdDev = 1.3083  t = 0.9629  p = 0.1678
#
# Iteration 355: Mean = 0.0049  StdDev = 1.2918  t = 0.3746  p = 0.3540
#
# Iteration 356: Mean = 0.0478  StdDev = 1.3002  t = 3.6627  p = 0.0001
#
# Iteration 357: Mean = 0.0179  StdDev = 1.3028  t = 1.3680  p = 0.0857
#
# Iteration 358: Mean = -0.0009  StdDev = 1.2885  t = -0.0727  p = 0.5290
#
# Iteration 359: Mean = 0.0029  StdDev = 1.2969  t = 0.2246  p = 0.4112
#
# Iteration 360: Mean = 0.0012  StdDev = 1.2856  t = 0.0927  p = 0.4631
#
# Iteration 361: Mean = 0.0317  StdDev = 1.3077  t = 2.4171  p = 0.0078
#
# Iteration 362: Mean = -0.0395  StdDev = 1.2800  t = -3.0772  p = 0.9990
#
# Iteration 363: Mean = -0.0049  StdDev = 1.2811  t = -0.3824  p = 0.6489
#
# Iteration 364: Mean = 0.0578  StdDev = 1.3123  t = 4.3861  p = 0.0000
#
# Iteration 365: Mean = 0.0162  StdDev = 1.2987  t = 1.2452  p = 0.1065
#
# Iteration 366: Mean = 0.0249  StdDev = 1.2769  t = 1.9458  p = 0.0258
#
# Iteration 367: Mean = -0.0291  StdDev = 1.3204  t = -2.1967  p = 0.9860
#
# Iteration 368: Mean = 0.0341  StdDev = 1.3055  t = 2.6029  p = 0.0046
#
# Iteration 369: Mean = -0.0176  StdDev = 1.2854  t = -1.3660  p = 0.9140
#
# Iteration 370: Mean = 0.0289  StdDev = 1.3124  t = 2.1938  p = 0.0141
#
# Iteration 371: Mean = -0.0242  StdDev = 1.2904  t = -1.8666  p = 0.9690
#
# Iteration 372: Mean = 0.0535  StdDev = 1.2564  t = 4.2411  p = 0.0000
#
# Iteration 373: Mean = 0.0528  StdDev = 1.3000  t = 4.0449  p = 0.0000
#
# Iteration 374: Mean = 0.0529  StdDev = 1.2973  t = 4.0602  p = 0.0000
#
# Iteration 375: Mean = -0.0177  StdDev = 1.2874  t = -1.3720  p = 0.9150
#
# Iteration 376: Mean = 0.0326  StdDev = 1.2801  t = 2.5374  p = 0.0056
#
# Iteration 377: Mean = -0.0107  StdDev = 1.2682  t = -0.8369  p = 0.7987
#
# Iteration 378: Mean = -0.0000  StdDev = 1.2788  t = -0.0026  p = 0.5010
#
# Iteration 379: Mean = 0.0194  StdDev = 1.2573  t = 1.5385  p = 0.0620
#
# Iteration 380: Mean = -0.0198  StdDev = 1.2921  t = -1.5266  p = 0.9366
#
# Iteration 381: Mean = 0.0135  StdDev = 1.2930  t = 1.0379  p = 0.1497
#
# Iteration 382: Mean = 0.0097  StdDev = 1.2784  t = 0.7556  p = 0.2249
#
# Iteration 383: Mean = -0.0099  StdDev = 1.2902  t = -0.7652  p = 0.7779
#
# Iteration 384: Mean = 0.0369  StdDev = 1.2503  t = 2.9372  p = 0.0017
#
# Iteration 385: Mean = -0.0418  StdDev = 1.3239  t = -3.1433  p = 0.9992
#
# Iteration 386: Mean = 0.0055  StdDev = 1.2805  t = 0.4318  p = 0.3330
#
# Iteration 387: Mean = 0.0259  StdDev = 1.2895  t = 1.9977  p = 0.0229
#
# Iteration 388: Mean = 0.0401  StdDev = 1.2657  t = 3.1546  p = 0.0008
#
# Iteration 389: Mean = -0.0197  StdDev = 1.2849  t = -1.5240  p = 0.9362
#
# Iteration 390: Mean = -0.0017  StdDev = 1.3031  t = -0.1337  p = 0.5532
#
# Iteration 391: Mean = -0.0322  StdDev = 1.2801  t = -2.5076  p = 0.9939
#
# Iteration 392: Mean = 0.0390  StdDev = 1.2571  t = 3.0942  p = 0.0010
#
# Iteration 393: Mean = 0.0341  StdDev = 1.2912  t = 2.6342  p = 0.0042
#
# Iteration 394: Mean = -0.0033  StdDev = 1.2727  t = -0.2615  p = 0.6031
#
# Iteration 395: Mean = 0.0247  StdDev = 1.2572  t = 1.9568  p = 0.0252
#
# Iteration 396: Mean = 0.0152  StdDev = 1.2913  t = 1.1692  p = 0.1212
#
# Iteration 397: Mean = 0.0510  StdDev = 1.2716  t = 3.9983  p = 0.0000
#
# Iteration 398: Mean = 0.0059  StdDev = 1.3032  t = 0.4482  p = 0.3270
#
# Iteration 399: Mean = 0.0701  StdDev = 1.2832  t = 5.4450  p = 0.0000
#
# Iteration 400: Mean = 0.0070  StdDev = 1.2952  t = 0.5397  p = 0.2947
#
# Iteration 401: Mean = 0.0401  StdDev = 1.2992  t = 3.0759  p = 0.0010
#
# Iteration 402: Mean = -0.0139  StdDev = 1.3083  t = -1.0550  p = 0.8543
#
# Iteration 403: Mean = 0.0003  StdDev = 1.2864  t = 0.0198  p = 0.4921
#
# Iteration 404: Mean = -0.0064  StdDev = 1.2985  t = -0.4927  p = 0.6889
#
# Iteration 405: Mean = 0.0213  StdDev = 1.3000  t = 1.6305  p = 0.0515
#
# Iteration 406: Mean = -0.0212  StdDev = 1.2841  t = -1.6463  p = 0.9501
#
# Iteration 407: Mean = 0.0448  StdDev = 1.2751  t = 3.5027  p = 0.0002
#
# Iteration 408: Mean = -0.0146  StdDev = 1.2817  t = -1.1367  p = 0.8722
#
# Iteration 409: Mean = -0.0201  StdDev = 1.2817  t = -1.5591  p = 0.9405
#
# Iteration 410: Mean = 0.0143  StdDev = 1.3007  t = 1.0939  p = 0.1370
#
# Iteration 411: Mean = -0.0453  StdDev = 1.2740  t = -3.5445  p = 0.9998
#
# Iteration 412: Mean = 0.0228  StdDev = 1.3061  t = 1.7386  p = 0.0411
#
# Iteration 413: Mean = -0.0305  StdDev = 1.3014  t = -2.3388  p = 0.9903
#
# Iteration 414: Mean = -0.0130  StdDev = 1.2801  t = -1.0129  p = 0.8445
#
# Iteration 415: Mean = 0.0710  StdDev = 1.3135  t = 5.3815  p = 0.0000
#
# Iteration 416: Mean = 0.0413  StdDev = 1.3216  t = 3.1098  p = 0.0009
#
# Iteration 417: Mean = -0.0138  StdDev = 1.2730  t = -1.0816  p = 0.8603
#
# Iteration 418: Mean = 0.0069  StdDev = 1.3132  t = 0.5217  p = 0.3009
#
# Iteration 419: Mean = 0.0107  StdDev = 1.2877  t = 0.8264  p = 0.2043
#
# Iteration 420: Mean = 0.0072  StdDev = 1.3127  t = 0.5477  p = 0.2920
#
# Iteration 421: Mean = -0.0081  StdDev = 1.2742  t = -0.6301  p = 0.7357
#
# Iteration 422: Mean = 0.0196  StdDev = 1.2852  t = 1.5215  p = 0.0641
#
# Iteration 423: Mean = 0.0473  StdDev = 1.2911  t = 3.6465  p = 0.0001
#
# Iteration 424: Mean = 0.0035  StdDev = 1.2939  t = 0.2671  p = 0.3947
#
# Iteration 425: Mean = 0.0251  StdDev = 1.2730  t = 1.9672  p = 0.0246
#
# Iteration 426: Mean = 0.0221  StdDev = 1.2968  t = 1.6997  p = 0.0446
#
# Iteration 427: Mean = 0.0112  StdDev = 1.2741  t = 0.8779  p = 0.1900
#
# Iteration 428: Mean = -0.0199  StdDev = 1.2993  t = -1.5245  p = 0.9363
#
# Iteration 429: Mean = -0.0035  StdDev = 1.3099  t = -0.2667  p = 0.6051
#
# Iteration 430: Mean = 0.0073  StdDev = 1.2563  t = 0.5750  p = 0.2827
#
# Iteration 431: Mean = 0.0658  StdDev = 1.2464  t = 5.2594  p = 0.0000
#
# Iteration 432: Mean = -0.0054  StdDev = 1.2887  t = -0.4143  p = 0.6607
#
# Iteration 433: Mean = -0.0238  StdDev = 1.2995  t = -1.8214  p = 0.9657
#
# Iteration 434: Mean = 0.0349  StdDev = 1.2758  t = 2.7217  p = 0.0032
#
# Iteration 435: Mean = -0.0200  StdDev = 1.3092  t = -1.5255  p = 0.9364
#
# Iteration 436: Mean = 0.0330  StdDev = 1.2997  t = 2.5280  p = 0.0057
#
# Iteration 437: Mean = -0.0036  StdDev = 1.2878  t = -0.2757  p = 0.6086
#
# Iteration 438: Mean = 0.0404  StdDev = 1.2812  t = 3.1430  p = 0.0008
#
# Iteration 439: Mean = 0.0141  StdDev = 1.2988  t = 1.0832  p = 0.1394
#
# Iteration 440: Mean = 0.0072  StdDev = 1.2893  t = 0.5553  p = 0.2893
#
# Iteration 441: Mean = 0.0328  StdDev = 1.2965  t = 2.5222  p = 0.0058
#
# Iteration 442: Mean = 0.0304  StdDev = 1.2704  t = 2.3811  p = 0.0086
#
# Iteration 443: Mean = 0.0080  StdDev = 1.3039  t = 0.6113  p = 0.2705
#
# Iteration 444: Mean = -0.0063  StdDev = 1.2687  t = -0.4933  p = 0.6891
#
# Iteration 445: Mean = -0.0113  StdDev = 1.2771  t = -0.8797  p = 0.8105
#
# Iteration 446: Mean = 0.0017  StdDev = 1.2909  t = 0.1332  p = 0.4470
#
# Iteration 447: Mean = -0.0214  StdDev = 1.3121  t = -1.6284  p = 0.9483
#
# Iteration 448: Mean = -0.0127  StdDev = 1.2952  t = -0.9761  p = 0.8355
#
# Iteration 449: Mean = 0.0085  StdDev = 1.3124  t = 0.6448  p = 0.2595
#
# Iteration 450: Mean = 0.0065  StdDev = 1.3063  t = 0.4975  p = 0.3094
#
# Iteration 451: Mean = 0.0103  StdDev = 1.2507  t = 0.8176  p = 0.2068
#
# Iteration 452: Mean = -0.0467  StdDev = 1.2790  t = -3.6412  p = 0.9999
#
# Iteration 453: Mean = -0.0273  StdDev = 1.2827  t = -2.1169  p = 0.9829
#
# Iteration 454: Mean = 0.0149  StdDev = 1.3215  t = 1.1237  p = 0.1306
#
# Iteration 455: Mean = 0.0190  StdDev = 1.3307  t = 1.4213  p = 0.0776
#
# Iteration 456: Mean = 0.0246  StdDev = 1.3045  t = 1.8758  p = 0.0303
#
# Iteration 457: Mean = 0.0170  StdDev = 1.3150  t = 1.2888  p = 0.0987
#
# Iteration 458: Mean = -0.0167  StdDev = 1.2797  t = -1.2992  p = 0.9031
#
# Iteration 459: Mean = 0.0064  StdDev = 1.2936  t = 0.4961  p = 0.3099
#
# Iteration 460: Mean = 0.0004  StdDev = 1.2761  t = 0.0295  p = 0.4882
#
# Iteration 461: Mean = 0.0040  StdDev = 1.2806  t = 0.3140  p = 0.3767
#
# Iteration 462: Mean = -0.0224  StdDev = 1.2689  t = -1.7563  p = 0.9605
#
# Iteration 463: Mean = 0.0285  StdDev = 1.2921  t = 2.1943  p = 0.0141
#
# Iteration 464: Mean = -0.0061  StdDev = 1.2933  t = -0.4675  p = 0.6799
#
# Iteration 465: Mean = -0.0092  StdDev = 1.2910  t = -0.7112  p = 0.7615
#
# Iteration 466: Mean = 0.0660  StdDev = 1.2873  t = 5.1087  p = 0.0000
#
# Iteration 467: Mean = -0.0012  StdDev = 1.2969  t = -0.0900  p = 0.5358
#
# Iteration 468: Mean = 0.0125  StdDev = 1.2665  t = 0.9825  p = 0.1629
#
# Iteration 469: Mean = 0.0403  StdDev = 1.3102  t = 3.0679  p = 0.0011
#
# Iteration 470: Mean = 0.0118  StdDev = 1.3105  t = 0.8967  p = 0.1849
#
# Iteration 471: Mean = 0.0262  StdDev = 1.2846  t = 2.0336  p = 0.0210
#
# Iteration 472: Mean = -0.0001  StdDev = 1.3016  t = -0.0053  p = 0.5021
#
# Iteration 473: Mean = -0.0075  StdDev = 1.2927  t = -0.5772  p = 0.7181
#
# Iteration 474: Mean = 0.0199  StdDev = 1.2825  t = 1.5477  p = 0.0608
#
# Iteration 475: Mean = -0.0188  StdDev = 1.2844  t = -1.4597  p = 0.9278
#
# Iteration 476: Mean = 0.0137  StdDev = 1.2855  t = 1.0635  p = 0.1438
#
# Iteration 477: Mean = 0.0058  StdDev = 1.2801  t = 0.4503  p = 0.3262
#
# Iteration 478: Mean = -0.0059  StdDev = 1.2932  t = -0.4574  p = 0.6763
#
# Iteration 479: Mean = -0.0562  StdDev = 1.2935  t = -4.3315  p = 1.0000
#
# Iteration 480: Mean = 0.0043  StdDev = 1.2920  t = 0.3347  p = 0.3689
#
# Iteration 481: Mean = 0.0506  StdDev = 1.3156  t = 3.8317  p = 0.0001
#
# Iteration 482: Mean = 0.0005  StdDev = 1.2975  t = 0.0354  p = 0.4859
#
# Iteration 483: Mean = -0.0468  StdDev = 1.2798  t = -3.6469  p = 0.9999
#
# Iteration 484: Mean = 0.0592  StdDev = 1.2830  t = 4.5992  p = 0.0000
#
# Iteration 485: Mean = 0.0213  StdDev = 1.2872  t = 1.6450  p = 0.0500
#
# Iteration 486: Mean = 0.0418  StdDev = 1.2997  t = 3.2029  p = 0.0007
#
# Iteration 487: Mean = -0.0097  StdDev = 1.2861  t = -0.7543  p = 0.7747
#
# Iteration 488: Mean = 0.0320  StdDev = 1.2918  t = 2.4659  p = 0.0068
#
# Iteration 489: Mean = 0.0356  StdDev = 1.2974  t = 2.7371  p = 0.0031
#
# Iteration 490: Mean = -0.0126  StdDev = 1.2930  t = -0.9671  p = 0.8333
#
# Iteration 491: Mean = -0.0255  StdDev = 1.2836  t = -1.9760  p = 0.9759
#
# Iteration 492: Mean = -0.0324  StdDev = 1.2980  t = -2.4896  p = 0.9936
#
# Iteration 493: Mean = 0.0066  StdDev = 1.3099  t = 0.5006  p = 0.3083
#
# Iteration 494: Mean = -0.0204  StdDev = 1.2749  t = -1.5955  p = 0.9447
#
# Iteration 495: Mean = 0.0221  StdDev = 1.2719  t = 1.7349  p = 0.0414
#
# Iteration 496: Mean = 0.0143  StdDev = 1.2911  t = 1.1010  p = 0.1355
#
# Iteration 497: Mean = -0.0150  StdDev = 1.2856  t = -1.1615  p = 0.8773
#
# Iteration 498: Mean = -0.0183  StdDev = 1.3056  t = -1.3959  p = 0.9186
#
# Iteration 499: Mean = 0.0025  StdDev = 1.2660  t = 0.1978  p = 0.4216
#
# Iteration 500: Mean = -0.0308  StdDev = 1.2807  t = -2.3960  p = 0.9917
#
# Iteration 501: Mean = 0.0219  StdDev = 1.3166  t = 1.6588  p = 0.0486
#
# Iteration 502: Mean = -0.0338  StdDev = 1.3016  t = -2.5884  p = 0.9952
#
# Iteration 503: Mean = 0.0019  StdDev = 1.3264  t = 0.1398  p = 0.4444
#
# Iteration 504: Mean = -0.0099  StdDev = 1.3077  t = -0.7520  p = 0.7740
#
# Iteration 505: Mean = 0.0259  StdDev = 1.3071  t = 1.9776  p = 0.0240
#
# Iteration 506: Mean = 0.0172  StdDev = 1.2913  t = 1.3234  p = 0.0929
#
# Iteration 507: Mean = -0.0041  StdDev = 1.3111  t = -0.3131  p = 0.6229
#
# Iteration 508: Mean = -0.0076  StdDev = 1.3311  t = -0.5663  p = 0.7144
#
# Iteration 509: Mean = 0.0244  StdDev = 1.2651  t = 1.9254  p = 0.0271
#
# Iteration 510: Mean = 0.0197  StdDev = 1.3232  t = 1.4817  p = 0.0692
#
# Iteration 511: Mean = -0.0343  StdDev = 1.2738  t = -2.6845  p = 0.9964
#
# Iteration 512: Mean = 0.0110  StdDev = 1.2708  t = 0.8647  p = 0.1936
#
# Iteration 513: Mean = 0.0147  StdDev = 1.2873  t = 1.1398  p = 0.1272
#
# Iteration 514: Mean = -0.0058  StdDev = 1.2866  t = -0.4521  p = 0.6744
#
# Iteration 515: Mean = 0.0514  StdDev = 1.3313  t = 3.8444  p = 0.0001
#
# Iteration 516: Mean = -0.0112  StdDev = 1.2826  t = -0.8673  p = 0.8071
#
# Iteration 517: Mean = 0.0203  StdDev = 1.2789  t = 1.5824  p = 0.0568
#
# Iteration 518: Mean = 0.0193  StdDev = 1.2891  t = 1.4925  p = 0.0678
#
# Iteration 519: Mean = -0.0247  StdDev = 1.3129  t = -1.8716  p = 0.9694
#
# Iteration 520: Mean = 0.0063  StdDev = 1.2936  t = 0.4825  p = 0.3147
#
# Iteration 521: Mean = 0.0376  StdDev = 1.2615  t = 2.9730  p = 0.0015
#
# Iteration 522: Mean = -0.0028  StdDev = 1.3074  t = -0.2168  p = 0.5858
#
# Iteration 523: Mean = 0.0357  StdDev = 1.2969  t = 2.7428  p = 0.0030
#
# Iteration 524: Mean = -0.0177  StdDev = 1.2951  t = -1.3628  p = 0.9135
#
# Iteration 525: Mean = 0.0134  StdDev = 1.2953  t = 1.0304  p = 0.1514
#
# Iteration 526: Mean = 0.0024  StdDev = 1.2743  t = 0.1850  p = 0.4266
#
# Iteration 527: Mean = -0.0079  StdDev = 1.2716  t = -0.6152  p = 0.7308
#
# Iteration 528: Mean = 0.0535  StdDev = 1.2911  t = 4.1300  p = 0.0000
#
# Iteration 529: Mean = 0.0362  StdDev = 1.3014  t = 2.7704  p = 0.0028
#
# Iteration 530: Mean = 0.0187  StdDev = 1.2787  t = 1.4559  p = 0.0727
#
# Iteration 531: Mean = -0.0150  StdDev = 1.3192  t = -1.1355  p = 0.8719
#
# Iteration 532: Mean = 0.0286  StdDev = 1.3091  t = 2.1772  p = 0.0147
#
# Iteration 533: Mean = -0.0293  StdDev = 1.2968  t = -2.2541  p = 0.9879
#
# Iteration 534: Mean = -0.0072  StdDev = 1.2761  t = -0.5644  p = 0.7138
#
# Iteration 535: Mean = -0.0037  StdDev = 1.3180  t = -0.2785  p = 0.6097
#
# Iteration 536: Mean = 0.0248  StdDev = 1.3141  t = 1.8802  p = 0.0300
#
# Iteration 537: Mean = -0.0008  StdDev = 1.2764  t = -0.0632  p = 0.5252
#
# Iteration 538: Mean = 0.0093  StdDev = 1.2859  t = 0.7203  p = 0.2357
#
# Iteration 539: Mean = 0.0192  StdDev = 1.3011  t = 1.4728  p = 0.0704
#
# Iteration 540: Mean = 0.0295  StdDev = 1.3066  t = 2.2469  p = 0.0123
#
# Iteration 541: Mean = -0.0163  StdDev = 1.2993  t = -1.2482  p = 0.8940
#
# Iteration 542: Mean = -0.0242  StdDev = 1.3237  t = -1.8234  p = 0.9659
#
# Iteration 543: Mean = -0.0080  StdDev = 1.2827  t = -0.6231  p = 0.7334
#
# Iteration 544: Mean = 0.0137  StdDev = 1.3135  t = 1.0361  p = 0.1501
#
# Iteration 545: Mean = 0.0225  StdDev = 1.2897  t = 1.7402  p = 0.0409
#
# Iteration 546: Mean = 0.0305  StdDev = 1.3175  t = 2.3031  p = 0.0106
#
# Iteration 547: Mean = 0.0327  StdDev = 1.2827  t = 2.5379  p = 0.0056
#
# Iteration 548: Mean = 0.0275  StdDev = 1.2810  t = 2.1409  p = 0.0161
#
# Iteration 549: Mean = 0.0370  StdDev = 1.2937  t = 2.8469  p = 0.0022
#
# Iteration 550: Mean = 0.0622  StdDev = 1.3247  t = 4.6805  p = 0.0000
#
# Iteration 551: Mean = -0.0041  StdDev = 1.2913  t = -0.3148  p = 0.6235
#
# Iteration 552: Mean = -0.0024  StdDev = 1.3229  t = -0.1789  p = 0.5710
#
# Iteration 553: Mean = 0.0329  StdDev = 1.2656  t = 2.5920  p = 0.0048
#
# Iteration 554: Mean = 0.0117  StdDev = 1.2477  t = 0.9321  p = 0.1756
#
# Iteration 555: Mean = -0.0266  StdDev = 1.2733  t = -2.0843  p = 0.9814
#
# Iteration 556: Mean = 0.0034  StdDev = 1.2853  t = 0.2606  p = 0.3972
#
# Iteration 557: Mean = 0.0169  StdDev = 1.2822  t = 1.3142  p = 0.0944
#
# Iteration 558: Mean = 0.0254  StdDev = 1.2948  t = 1.9545  p = 0.0253
#
# Iteration 559: Mean = -0.0075  StdDev = 1.2765  t = -0.5844  p = 0.7205
#
# Iteration 560: Mean = 0.0123  StdDev = 1.2810  t = 0.9565  p = 0.1694
#
# Iteration 561: Mean = 0.0124  StdDev = 1.3009  t = 0.9498  p = 0.1711
#
# Iteration 562: Mean = -0.0509  StdDev = 1.2847  t = -3.9465  p = 1.0000
#
# Iteration 563: Mean = 0.0305  StdDev = 1.3062  t = 2.3295  p = 0.0099
#
# Iteration 564: Mean = 0.0053  StdDev = 1.2768  t = 0.4111  p = 0.3405
#
# Iteration 565: Mean = 0.0249  StdDev = 1.2584  t = 1.9704  p = 0.0244
#
# Iteration 566: Mean = 0.0460  StdDev = 1.3145  t = 3.4865  p = 0.0002
#
# Iteration 567: Mean = 0.0172  StdDev = 1.2915  t = 1.3285  p = 0.0920
#
# Iteration 568: Mean = 0.0271  StdDev = 1.2827  t = 2.1083  p = 0.0175
#
# Iteration 569: Mean = 0.0319  StdDev = 1.2692  t = 2.5055  p = 0.0061
#
# Iteration 570: Mean = 0.0517  StdDev = 1.2592  t = 4.0882  p = 0.0000
#
# Iteration 571: Mean = -0.0087  StdDev = 1.2903  t = -0.6740  p = 0.7498
#
# Iteration 572: Mean = 0.0175  StdDev = 1.2680  t = 1.3728  p = 0.0849
#
# Iteration 573: Mean = 0.0469  StdDev = 1.3178  t = 3.5479  p = 0.0002
#
# Iteration 574: Mean = 0.0458  StdDev = 1.2538  t = 3.6400  p = 0.0001
#
# Iteration 575: Mean = -0.0036  StdDev = 1.2895  t = -0.2773  p = 0.6092
#
# Iteration 576: Mean = -0.0053  StdDev = 1.3016  t = -0.4060  p = 0.6576
#
# Iteration 577: Mean = -0.0219  StdDev = 1.2794  t = -1.7068  p = 0.9561
#
# Iteration 578: Mean = -0.0027  StdDev = 1.2975  t = -0.2053  p = 0.5813
#
# Iteration 579: Mean = -0.0130  StdDev = 1.2890  t = -1.0036  p = 0.8422
#
# Iteration 580: Mean = 0.0295  StdDev = 1.3296  t = 2.2080  p = 0.0136
#
# Iteration 581: Mean = 0.0194  StdDev = 1.3206  t = 1.4640  p = 0.0716
#
# Iteration 582: Mean = 0.0278  StdDev = 1.2955  t = 2.1341  p = 0.0164
#
# Iteration 583: Mean = -0.0266  StdDev = 1.3209  t = -2.0078  p = 0.9777
#
# Iteration 584: Mean = 0.0216  StdDev = 1.3007  t = 1.6560  p = 0.0489
#
# Iteration 585: Mean = 0.0062  StdDev = 1.2698  t = 0.4896  p = 0.3122
#
# Iteration 586: Mean = 0.0019  StdDev = 1.2830  t = 0.1489  p = 0.4408
#
# Iteration 587: Mean = 0.0310  StdDev = 1.2930  t = 2.3872  p = 0.0085
#
# Iteration 588: Mean = -0.0021  StdDev = 1.2927  t = -0.1601  p = 0.5636
#
# Iteration 589: Mean = 0.0073  StdDev = 1.2909  t = 0.5664  p = 0.2856
#
# Iteration 590: Mean = -0.0042  StdDev = 1.3100  t = -0.3185  p = 0.6249
#
# Iteration 591: Mean = 0.0157  StdDev = 1.3018  t = 1.2019  p = 0.1147
#
# Iteration 592: Mean = 0.0038  StdDev = 1.2893  t = 0.2939  p = 0.3844
#
# Iteration 593: Mean = 0.0032  StdDev = 1.2894  t = 0.2467  p = 0.4026
#
# Iteration 594: Mean = 0.0182  StdDev = 1.2851  t = 1.4136  p = 0.0787
#
# Iteration 595: Mean = 0.0374  StdDev = 1.3158  t = 2.8285  p = 0.0023
#
# Iteration 596: Mean = 0.0056  StdDev = 1.2770  t = 0.4332  p = 0.3324
#
# Iteration 597: Mean = 0.0051  StdDev = 1.2803  t = 0.4004  p = 0.3444
#
# Iteration 598: Mean = 0.0641  StdDev = 1.2815  t = 4.9810  p = 0.0000
#
# Iteration 599: Mean = 0.0216  StdDev = 1.2798  t = 1.6794  p = 0.0465
#
# Iteration 600: Mean = 0.0277  StdDev = 1.2757  t = 2.1605  p = 0.0154
#
# Iteration 601: Mean = -0.0338  StdDev = 1.2930  t = -2.6007  p = 0.9953
#
# Iteration 602: Mean = -0.0055  StdDev = 1.3024  t = -0.4210  p = 0.6631
#
# Iteration 603: Mean = 0.0561  StdDev = 1.2992  t = 4.3006  p = 0.0000
#
# Iteration 604: Mean = -0.0035  StdDev = 1.2915  t = -0.2672  p = 0.6053
#
# Iteration 605: Mean = 0.0556  StdDev = 1.2997  t = 4.2586  p = 0.0000
#
# Iteration 606: Mean = 0.0241  StdDev = 1.2961  t = 1.8512  p = 0.0321
#
# Iteration 607: Mean = 0.0079  StdDev = 1.3070  t = 0.6017  p = 0.2737
#
# Iteration 608: Mean = 0.0480  StdDev = 1.2931  t = 3.6980  p = 0.0001
#
# Iteration 609: Mean = 0.0043  StdDev = 1.2795  t = 0.3359  p = 0.3685
#
# Iteration 610: Mean = -0.0069  StdDev = 1.3355  t = -0.5151  p = 0.6968
#
# Iteration 611: Mean = -0.0035  StdDev = 1.2859  t = -0.2716  p = 0.6070
#
# Iteration 612: Mean = -0.0251  StdDev = 1.3024  t = -1.9197  p = 0.9726
#
# Iteration 613: Mean = 0.0224  StdDev = 1.2935  t = 1.7263  p = 0.0421
#
# Iteration 614: Mean = -0.0295  StdDev = 1.2622  t = -2.3290  p = 0.9901
#
# Iteration 615: Mean = 0.0325  StdDev = 1.2958  t = 2.5006  p = 0.0062
#
# Iteration 616: Mean = 0.0460  StdDev = 1.3025  t = 3.5202  p = 0.0002
#
# Iteration 617: Mean = -0.0121  StdDev = 1.3047  t = -0.9206  p = 0.8214
#
# Iteration 618: Mean = 0.0083  StdDev = 1.2853  t = 0.6440  p = 0.2598
#
# Iteration 619: Mean = -0.0093  StdDev = 1.2916  t = -0.7182  p = 0.7637
#
# Iteration 620: Mean = 0.0043  StdDev = 1.3074  t = 0.3305  p = 0.3705
#
# Iteration 621: Mean = 0.0150  StdDev = 1.2920  t = 1.1535  p = 0.1243
#
# Iteration 622: Mean = 0.0602  StdDev = 1.2914  t = 4.6471  p = 0.0000
#
# Iteration 623: Mean = -0.0254  StdDev = 1.2781  t = -1.9812  p = 0.9762
#
# Iteration 624: Mean = 0.0397  StdDev = 1.2990  t = 3.0442  p = 0.0012
#
# Iteration 625: Mean = 0.0085  StdDev = 1.3207  t = 0.6398  p = 0.2612
#
# Iteration 626: Mean = 0.0447  StdDev = 1.2923  t = 3.4498  p = 0.0003
#
# Iteration 627: Mean = -0.0040  StdDev = 1.3199  t = -0.3006  p = 0.6182
#
# Iteration 628: Mean = 0.0102  StdDev = 1.2893  t = 0.7862  p = 0.2159
#
# Iteration 629: Mean = 0.0076  StdDev = 1.2838  t = 0.5922  p = 0.2769
#
# Iteration 630: Mean = -0.0370  StdDev = 1.3051  t = -2.8211  p = 0.9976
#
# Iteration 631: Mean = 0.0162  StdDev = 1.3125  t = 1.2326  p = 0.1089
#
# Iteration 632: Mean = 0.0149  StdDev = 1.3054  t = 1.1390  p = 0.1274
#
# Iteration 633: Mean = 0.0026  StdDev = 1.2982  t = 0.2009  p = 0.4204
#
# Iteration 634: Mean = 0.0161  StdDev = 1.2987  t = 1.2357  p = 0.1083
#
# Iteration 635: Mean = -0.0080  StdDev = 1.2755  t = -0.6259  p = 0.7343
#
# Iteration 636: Mean = 0.0441  StdDev = 1.2963  t = 3.3931  p = 0.0003
#
# Iteration 637: Mean = 0.0255  StdDev = 1.3104  t = 1.9407  p = 0.0261
#
# Iteration 638: Mean = 0.0344  StdDev = 1.2874  t = 2.6624  p = 0.0039
#
# Iteration 639: Mean = 0.0516  StdDev = 1.2706  t = 4.0461  p = 0.0000
#
# Iteration 640: Mean = -0.0082  StdDev = 1.3265  t = -0.6123  p = 0.7298
#
# Iteration 641: Mean = 0.0042  StdDev = 1.2984  t = 0.3205  p = 0.3743
#
# Iteration 642: Mean = 0.0348  StdDev = 1.3262  t = 2.6122  p = 0.0045
#
# Iteration 643: Mean = -0.0431  StdDev = 1.2907  t = -3.3289  p = 0.9996
#
# Iteration 644: Mean = 0.0008  StdDev = 1.2594  t = 0.0634  p = 0.4747
#
# Iteration 645: Mean = 0.0563  StdDev = 1.2915  t = 4.3465  p = 0.0000
#
# Iteration 646: Mean = 0.0138  StdDev = 1.2930  t = 1.0601  p = 0.1446
#
# Iteration 647: Mean = -0.0189  StdDev = 1.3307  t = -1.4181  p = 0.9219
#
# Iteration 648: Mean = 0.0276  StdDev = 1.3017  t = 2.1129  p = 0.0173
#
# Iteration 649: Mean = 0.0789  StdDev = 1.3016  t = 6.0401  p = 0.0000
#
# Iteration 650: Mean = 0.0406  StdDev = 1.3039  t = 3.0985  p = 0.0010
#
# Iteration 651: Mean = -0.0150  StdDev = 1.2887  t = -1.1584  p = 0.8767
#
# Iteration 652: Mean = -0.0375  StdDev = 1.3370  t = -2.7979  p = 0.9974
#
# Iteration 653: Mean = 0.0092  StdDev = 1.2788  t = 0.7201  p = 0.2357
#
# Iteration 654: Mean = -0.0644  StdDev = 1.2813  t = -5.0068  p = 1.0000
#
# Iteration 655: Mean = 0.0093  StdDev = 1.2990  t = 0.7096  p = 0.2390
#
# Iteration 656: Mean = 0.0322  StdDev = 1.2798  t = 2.5073  p = 0.0061
#
# Iteration 657: Mean = -0.0168  StdDev = 1.3032  t = -1.2816  p = 0.9000
#
# Iteration 658: Mean = -0.0082  StdDev = 1.2969  t = -0.6274  p = 0.7348
#
# Iteration 659: Mean = -0.0161  StdDev = 1.2721  t = -1.2640  p = 0.8969
#
# Iteration 660: Mean = -0.0160  StdDev = 1.3192  t = -1.2100  p = 0.8869
#
# Iteration 661: Mean = 0.0123  StdDev = 1.2900  t = 0.9518  p = 0.1706
#
# Iteration 662: Mean = -0.0023  StdDev = 1.3055  t = -0.1764  p = 0.5700
#
# Iteration 663: Mean = -0.0032  StdDev = 1.2963  t = -0.2462  p = 0.5972
#
# Iteration 664: Mean = 0.0062  StdDev = 1.2932  t = 0.4771  p = 0.3167
#
# Iteration 665: Mean = 0.0172  StdDev = 1.2827  t = 1.3391  p = 0.0903
#
# Iteration 666: Mean = -0.0156  StdDev = 1.3081  t = -1.1882  p = 0.8826
#
# Iteration 667: Mean = -0.0237  StdDev = 1.2860  t = -1.8335  p = 0.9666
#
# Iteration 668: Mean = 0.0797  StdDev = 1.2735  t = 6.2355  p = 0.0000
#
# Iteration 669: Mean = 0.0445  StdDev = 1.3139  t = 3.3768  p = 0.0004
#
# ...
#
# Iteration 783: Mean = -0.0034  StdDev = 1.2770  t = -0.2680  p = 0.6057
#
# Iteration 784: Mean = -0.0436  StdDev = 1.3119  t = -3.3104  p = 0.9995
#
# Iteration 785: Mean = -0.0175  StdDev = 1.3027  t = -1.3399  p = 0.9099
#
# Iteration 786: Mean = 0.0470  StdDev = 1.2701  t = 3.6892  p = 0.0001
#
# Iteration 787: Mean = 0.0387  StdDev = 1.3013  t = 2.9652  p = 0.0015
#
# Iteration 788: Mean = 0.0538  StdDev = 1.3065  t = 4.1056  p = 0.0000
#
# Iteration 789: Mean = 0.0043  StdDev = 1.2859  t = 0.3312  p = 0.3702
#
# Iteration 790: Mean = 0.0134  StdDev = 1.3218  t = 1.0122  p = 0.1557
#
# Iteration 791: Mean = 0.0179  StdDev = 1.2638  t = 1.4138  p = 0.0787
#
# Iteration 792: Mean = -0.0016  StdDev = 1.3072  t = -0.1228  p = 0.5489
#
# Iteration 793: Mean = -0.0333  StdDev = 1.3187  t = -2.5189  p = 0.9941
#
# Iteration 794: Mean = -0.0339  StdDev = 1.3268  t = -2.5422  p = 0.9945
#
# Iteration 795: Mean = 0.0065  StdDev = 1.2848  t = 0.5009  p = 0.3082
#
# Iteration 796: Mean = 0.0185  StdDev = 1.3030  t = 1.4162  p = 0.0784
#
# Iteration 797: Mean = -0.0065  StdDev = 1.3108  t = -0.4927  p = 0.6889
#
# Iteration 798: Mean = 0.0326  StdDev = 1.2971  t = 2.5043  p = 0.0061
#
# Iteration 799: Mean = 0.0002  StdDev = 1.2819  t = 0.0157  p = 0.4937
#
# Iteration 800: Mean = 0.0181  StdDev = 1.2790  t = 1.4064  p = 0.0798
#
# Iteration 801: Mean = -0.0068  StdDev = 1.3176  t = -0.5172  p = 0.6975
#
# Iteration 802: Mean = -0.0331  StdDev = 1.3067  t = -2.5269  p = 0.9942
#
# Iteration 803: Mean = -0.0182  StdDev = 1.3058  t = -1.3869  p = 0.9173
#
# Iteration 804: Mean = -0.0144  StdDev = 1.2650  t = -1.1317  p = 0.8711
#
# Iteration 805: Mean = 0.0105  StdDev = 1.2814  t = 0.8161  p = 0.2072
#
# Iteration 806: Mean = 0.0141  StdDev = 1.2914  t = 1.0844  p = 0.1391
#
# Iteration 807: Mean = -0.0053  StdDev = 1.3015  t = -0.4033  p = 0.6567
#
# Iteration 808: Mean = 0.0207  StdDev = 1.2781  t = 1.6138  p = 0.0533
#
# Iteration 809: Mean = 0.0039  StdDev = 1.3149  t = 0.2937  p = 0.3845
#
# Iteration 810: Mean = 0.0166  StdDev = 1.2955  t = 1.2791  p = 0.1004
#
# Iteration 811: Mean = -0.0527  StdDev = 1.3121  t = -4.0025  p = 1.0000
#
# Iteration 812: Mean = -0.0434  StdDev = 1.2873  t = -3.3610  p = 0.9996
#
# Iteration 813: Mean = 0.0619  StdDev = 1.2943  t = 4.7655  p = 0.0000
#
# Iteration 814: Mean = -0.0121  StdDev = 1.3131  t = -0.9190  p = 0.8210
#
# Iteration 815: Mean = 0.0439  StdDev = 1.2814  t = 3.4097  p = 0.0003
#
# Iteration 816: Mean = -0.0072  StdDev = 1.2702  t = -0.5686  p = 0.7152
#
# Iteration 817: Mean = 0.0282  StdDev = 1.2695  t = 2.2168  p = 0.0133
#
# Iteration 818: Mean = -0.0134  StdDev = 1.2887  t = -1.0398  p = 0.8508
#
# Iteration 819: Mean = -0.0251  StdDev = 1.2673  t = -1.9759  p = 0.9759
#
# Iteration 820: Mean = -0.0186  StdDev = 1.2911  t = -1.4325  p = 0.9240
#
# Iteration 821: Mean = 0.0275  StdDev = 1.2919  t = 2.1186  p = 0.0171
#
# Iteration 822: Mean = 0.0018  StdDev = 1.2523  t = 0.1453  p = 0.4423
#
# Iteration 823: Mean = -0.0391  StdDev = 1.2538  t = -3.1062  p = 0.9991
#
# Iteration 824: Mean = -0.0067  StdDev = 1.2743  t = -0.5208  p = 0.6988
#
# Iteration 825: Mean = -0.0075  StdDev = 1.3040  t = -0.5768  p = 0.7180
#
# Iteration 826: Mean = -0.0533  StdDev = 1.3227  t = -4.0136  p = 1.0000
#
# Iteration 827: Mean = 0.0064  StdDev = 1.3035  t = 0.4924  p = 0.3112
#
# Iteration 828: Mean = 0.0004  StdDev = 1.3209  t = 0.0293  p = 0.4883
#
# Iteration 829: Mean = 0.0441  StdDev = 1.2773  t = 3.4383  p = 0.0003
#
# Iteration 830: Mean = -0.0157  StdDev = 1.2692  t = -1.2325  p = 0.8911
#
# Iteration 831: Mean = 0.0057  StdDev = 1.2856  t = 0.4390  p = 0.3303
#
# Iteration 832: Mean = 0.0004  StdDev = 1.2597  t = 0.0289  p = 0.4885
#
# Iteration 833: Mean = 0.0178  StdDev = 1.3112  t = 1.3500  p = 0.0885
#
# Iteration 834: Mean = -0.0153  StdDev = 1.2963  t = -1.1759  p = 0.8802
#
# Iteration 835: Mean = 0.0052  StdDev = 1.2611  t = 0.4135  p = 0.3396
#
# Iteration 836: Mean = -0.0252  StdDev = 1.2831  t = -1.9529  p = 0.9746
#
# Iteration 837: Mean = -0.0316  StdDev = 1.2905  t = -2.4427  p = 0.9927
#
# Iteration 838: Mean = 0.0244  StdDev = 1.3000  t = 1.8700  p = 0.0307
#
# Iteration 839: Mean = -0.0051  StdDev = 1.2901  t = -0.3945  p = 0.6534
#
# Iteration 840: Mean = 0.0622  StdDev = 1.3055  t = 4.7446  p = 0.0000
#
# Iteration 841: Mean = -0.0653  StdDev = 1.2553  t = -5.1789  p = 1.0000
#
# Iteration 842: Mean = 0.0005  StdDev = 1.2980  t = 0.0357  p = 0.4858
#
# Iteration 843: Mean = 0.0013  StdDev = 1.2773  t = 0.1003  p = 0.4601
#
# Iteration 844: Mean = 0.0175  StdDev = 1.2788  t = 1.3623  p = 0.0866
#
# Iteration 845: Mean = 0.0314  StdDev = 1.2728  t = 2.4600  p = 0.0069
#
# Iteration 846: Mean = 0.0235  StdDev = 1.2766  t = 1.8345  p = 0.0333
#
# Iteration 847: Mean = 0.0089  StdDev = 1.2913  t = 0.6890  p = 0.2454
#
# Iteration 848: Mean = 0.0187  StdDev = 1.2896  t = 1.4471  p = 0.0739
#
# Iteration 849: Mean = 0.0157  StdDev = 1.2841  t = 1.2220  p = 0.1109
#
# Iteration 850: Mean = 0.0079  StdDev = 1.3065  t = 0.5996  p = 0.2744
#
# Iteration 851: Mean = 0.0021  StdDev = 1.2930  t = 0.1635  p = 0.4351
#
# Iteration 852: Mean = 0.0561  StdDev = 1.2975  t = 4.3069  p = 0.0000
#
# Iteration 853: Mean = 0.0152  StdDev = 1.3183  t = 1.1502  p = 0.1250
#
# Iteration 854: Mean = -0.0095  StdDev = 1.2805  t = -0.7365  p = 0.7693
#
# Iteration 855: Mean = 0.0144  StdDev = 1.2919  t = 1.1090  p = 0.1337
#
# Iteration 856: Mean = 0.0121  StdDev = 1.3178  t = 0.9111  p = 0.1811
#
# Iteration 857: Mean = 0.0003  StdDev = 1.3146  t = 0.0234  p = 0.4907
#
# Iteration 858: Mean = -0.0160  StdDev = 1.2924  t = -1.2323  p = 0.8911
#
# Iteration 859: Mean = -0.0010  StdDev = 1.2869  t = -0.0804  p = 0.5320
#
# Iteration 860: Mean = 0.0225  StdDev = 1.3032  t = 1.7199  p = 0.0427
#
# Iteration 861: Mean = -0.0309  StdDev = 1.3265  t = -2.3181  p = 0.9898
#
# Iteration 862: Mean = 0.0278  StdDev = 1.3068  t = 2.1220  p = 0.0169
#
# Iteration 863: Mean = 0.0225  StdDev = 1.2852  t = 1.7406  p = 0.0409
#
# Iteration 864: Mean = 0.0377  StdDev = 1.2896  t = 2.9118  p = 0.0018
#
# Iteration 865: Mean = -0.0157  StdDev = 1.2839  t = -1.2167  p = 0.8881
#
# Iteration 866: Mean = -0.0404  StdDev = 1.2745  t = -3.1590  p = 0.9992
#
# Iteration 867: Mean = 0.0063  StdDev = 1.2637  t = 0.4951  p = 0.3103
#
# Iteration 868: Mean = 0.0248  StdDev = 1.3062  t = 1.8880  p = 0.0295
#
# Iteration 869: Mean = 0.0282  StdDev = 1.2782  t = 2.2009  p = 0.0139
#
# Iteration 870: Mean = -0.0037  StdDev = 1.2978  t = -0.2849  p = 0.6121
#
# Iteration 871: Mean = -0.0089  StdDev = 1.2766  t = -0.6971  p = 0.7571
#
# Iteration 872: Mean = -0.0192  StdDev = 1.2692  t = -1.5057  p = 0.9339
#
# Iteration 873: Mean = 0.0335  StdDev = 1.2947  t = 2.5814  p = 0.0049
#
# Iteration 874: Mean = 0.0012  StdDev = 1.2849  t = 0.0928  p = 0.4630
#
# Iteration 875: Mean = -0.0463  StdDev = 1.2971  t = -3.5587  p = 0.9998
#
# Iteration 876: Mean = 0.0033  StdDev = 1.2854  t = 0.2554  p = 0.3992
#
# Iteration 877: Mean = 0.0105  StdDev = 1.3024  t = 0.8041  p = 0.2107
#
# Iteration 878: Mean = 0.0332  StdDev = 1.2885  t = 2.5687  p = 0.0051
#
# Iteration 879: Mean = 0.0178  StdDev = 1.3173  t = 1.3463  p = 0.0891
#
# Iteration 880: Mean = -0.0348  StdDev = 1.3026  t = -2.6605  p = 0.9961
#
# Iteration 881: Mean = 0.0169  StdDev = 1.2531  t = 1.3402  p = 0.0901
#
# Iteration 882: Mean = 0.0143  StdDev = 1.2523  t = 1.1381  p = 0.1275
#
# Iteration 883: Mean = 0.0478  StdDev = 1.3125  t = 3.6262  p = 0.0001
#
# Iteration 884: Mean = 0.0034  StdDev = 1.3038  t = 0.2601  p = 0.3974
#
# Iteration 885: Mean = 0.0068  StdDev = 1.2811  t = 0.5312  p = 0.2976
#
# Iteration 886: Mean = 0.0201  StdDev = 1.3084  t = 1.5317  p = 0.0628
#
# Iteration 887: Mean = 0.0352  StdDev = 1.2812  t = 2.7346  p = 0.0031
#
# Iteration 888: Mean = 0.0323  StdDev = 1.3009  t = 2.4749  p = 0.0067
#
# Iteration 889: Mean = -0.0132  StdDev = 1.3310  t = -0.9866  p = 0.8381
#
# Iteration 890: Mean = -0.0171  StdDev = 1.2945  t = -1.3138  p = 0.9055
#
# Iteration 891: Mean = 0.0332  StdDev = 1.2888  t = 2.5673  p = 0.0051
#
# Iteration 892: Mean = 0.0162  StdDev = 1.2997  t = 1.2405  p = 0.1074
#
# Iteration 893: Mean = 0.0388  StdDev = 1.2626  t = 3.0596  p = 0.0011
#
# Iteration 894: Mean = -0.0330  StdDev = 1.2642  t = -2.6018  p = 0.9954
#
# Iteration 895: Mean = -0.0073  StdDev = 1.2895  t = -0.5633  p = 0.7134
#
# Iteration 896: Mean = 0.0030  StdDev = 1.2668  t = 0.2344  p = 0.4073
#
# Iteration 897: Mean = 0.0467  StdDev = 1.2977  t = 3.5890  p = 0.0002
#
# Iteration 898: Mean = 0.0297  StdDev = 1.2972  t = 2.2841  p = 0.0112
#
# Iteration 899: Mean = 0.0007  StdDev = 1.3214  t = 0.0495  p = 0.4803
#
# Iteration 900: Mean = 0.0588  StdDev = 1.2866  t = 4.5552  p = 0.0000
#
# Iteration 901: Mean = 0.0456  StdDev = 1.2996  t = 3.4983  p = 0.0002
#
# Iteration 902: Mean = -0.0105  StdDev = 1.2971  t = -0.8098  p = 0.7910
#
# Iteration 903: Mean = 0.0278  StdDev = 1.3171  t = 2.1052  p = 0.0176
#
# Iteration 904: Mean = 0.0138  StdDev = 1.2930  t = 1.0631  p = 0.1439
#
# Iteration 905: Mean = 0.0088  StdDev = 1.2902  t = 0.6778  p = 0.2489
#
# Iteration 906: Mean = 0.0082  StdDev = 1.2972  t = 0.6270  p = 0.2653
#
# Iteration 907: Mean = 0.0285  StdDev = 1.3016  t = 2.1829  p = 0.0145
#
# Iteration 908: Mean = 0.0083  StdDev = 1.3019  t = 0.6374  p = 0.2619
#
# Iteration 909: Mean = -0.0243  StdDev = 1.3289  t = -1.8210  p = 0.9657
#
# Iteration 910: Mean = 0.0088  StdDev = 1.2858  t = 0.6781  p = 0.2489
#
# Iteration 911: Mean = -0.0045  StdDev = 1.2738  t = -0.3554  p = 0.6389
#
# Iteration 912: Mean = -0.0039  StdDev = 1.2827  t = -0.2991  p = 0.6176
#
# Iteration 913: Mean = 0.0370  StdDev = 1.2974  t = 2.8416  p = 0.0022
#
# Iteration 914: Mean = 0.0286  StdDev = 1.3173  t = 2.1622  p = 0.0153
#
# Iteration 915: Mean = -0.0254  StdDev = 1.2934  t = -1.9572  p = 0.9748
#
# Iteration 916: Mean = 0.0312  StdDev = 1.2873  t = 2.4159  p = 0.0078
#
# Iteration 917: Mean = 0.0565  StdDev = 1.2766  t = 4.4103  p = 0.0000
#
# Iteration 918: Mean = -0.0357  StdDev = 1.3278  t = -2.6773  p = 0.9963
#
# Iteration 919: Mean = 0.0383  StdDev = 1.3139  t = 2.9014  p = 0.0019
#
# Iteration 920: Mean = -0.0305  StdDev = 1.2946  t = -2.3471  p = 0.9905
#
# Iteration 921: Mean = -0.0071  StdDev = 1.3181  t = -0.5371  p = 0.7044
#
# Iteration 922: Mean = -0.0018  StdDev = 1.2799  t = -0.1436  p = 0.5571
#
# Iteration 923: Mean = 0.0280  StdDev = 1.2874  t = 2.1654  p = 0.0152
#
# Iteration 924: Mean = 0.0194  StdDev = 1.2677  t = 1.5272  p = 0.0634
#
# Iteration 925: Mean = 0.0033  StdDev = 1.3058  t = 0.2487  p = 0.4018
#
# Iteration 926: Mean = -0.0131  StdDev = 1.2600  t = -1.0372  p = 0.8502
#
# Iteration 927: Mean = -0.0039  StdDev = 1.3138  t = -0.2992  p = 0.6176
#
# Iteration 928: Mean = -0.0105  StdDev = 1.2885  t = -0.8136  p = 0.7921
#
# Iteration 929: Mean = 0.0073  StdDev = 1.2629  t = 0.5786  p = 0.2814
#
# Iteration 930: Mean = 0.0075  StdDev = 1.2959  t = 0.5733  p = 0.2832
#
# Iteration 931: Mean = -0.0000  StdDev = 1.2833  t = -0.0033  p = 0.5013
#
# Iteration 932: Mean = 0.0149  StdDev = 1.2913  t = 1.1473  p = 0.1256
#
# Iteration 933: Mean = -0.0209  StdDev = 1.2757  t = -1.6311  p = 0.9486
#
# Iteration 934: Mean = 0.0150  StdDev = 1.2819  t = 1.1694  p = 0.1211
#
# Iteration 935: Mean = 0.0137  StdDev = 1.3141  t = 1.0393  p = 0.1493
#
# Iteration 936: Mean = 0.0223  StdDev = 1.2996  t = 1.7083  p = 0.0438
#
# Iteration 937: Mean = 0.0284  StdDev = 1.2773  t = 2.2155  p = 0.0134
#
# Iteration 938: Mean = -0.0594  StdDev = 1.2698  t = -4.6623  p = 1.0000
#
# Iteration 939: Mean = -0.0203  StdDev = 1.2903  t = -1.5693  p = 0.9417
#
# Iteration 940: Mean = 0.0127  StdDev = 1.3124  t = 0.9620  p = 0.1680
#
# Iteration 941: Mean = 0.0278  StdDev = 1.3043  t = 2.1207  p = 0.0170
#
# Iteration 942: Mean = 0.0061  StdDev = 1.2575  t = 0.4824  p = 0.3148
#
# Iteration 943: Mean = 0.0193  StdDev = 1.3013  t = 1.4768  p = 0.0699
#
# Iteration 944: Mean = 0.0135  StdDev = 1.3191  t = 1.0194  p = 0.1540
#
# Iteration 945: Mean = 0.0715  StdDev = 1.3002  t = 5.4794  p = 0.0000
#
# Iteration 946: Mean = 0.0001  StdDev = 1.3063  t = 0.0107  p = 0.4957
#
# Iteration 947: Mean = 0.0122  StdDev = 1.2973  t = 0.9346  p = 0.1750
#
# Iteration 948: Mean = -0.0122  StdDev = 1.2851  t = -0.9491  p = 0.8287
#
# Iteration 949: Mean = 0.0539  StdDev = 1.2890  t = 4.1642  p = 0.0000
#
# Iteration 950: Mean = 0.0061  StdDev = 1.2761  t = 0.4798  p = 0.3157
#
# Iteration 951: Mean = 0.0414  StdDev = 1.2938  t = 3.1865  p = 0.0007
#
# Iteration 952: Mean = 0.0149  StdDev = 1.2995  t = 1.1408  p = 0.1270
#
# Iteration 953: Mean = -0.0387  StdDev = 1.2920  t = -2.9871  p = 0.9986
#
# Iteration 954: Mean = -0.0198  StdDev = 1.2810  t = -1.5376  p = 0.9379
#
# Iteration 955: Mean = 0.0162  StdDev = 1.2909  t = 1.2505  p = 0.1056
#
# Iteration 956: Mean = 0.0090  StdDev = 1.3220  t = 0.6748  p = 0.2499
#
# Iteration 957: Mean = -0.0026  StdDev = 1.2827  t = -0.2021  p = 0.5801
#
# Iteration 958: Mean = 0.0175  StdDev = 1.2662  t = 1.3758  p = 0.0844
#
# Iteration 959: Mean = -0.0521  StdDev = 1.3092  t = -3.9653  p = 1.0000
#
# Iteration 960: Mean = 0.0129  StdDev = 1.2747  t = 1.0053  p = 0.1574
#
# Iteration 961: Mean = 0.0362  StdDev = 1.3109  t = 2.7523  p = 0.0030
#
# Iteration 962: Mean = 0.0024  StdDev = 1.3264  t = 0.1826  p = 0.4275
#
# Iteration 963: Mean = -0.0254  StdDev = 1.3004  t = -1.9488  p = 0.9743
#
# Iteration 964: Mean = -0.0223  StdDev = 1.3190  t = -1.6817  p = 0.9537
#
# Iteration 965: Mean = 0.0222  StdDev = 1.2675  t = 1.7439  p = 0.0406
#
# Iteration 966: Mean = 0.0182  StdDev = 1.2873  t = 1.4113  p = 0.0791
#
# Iteration 967: Mean = 0.0031  StdDev = 1.2910  t = 0.2384  p = 0.4058
#
# Iteration 968: Mean = 0.0244  StdDev = 1.3048  t = 1.8621  p = 0.0313
#
# Iteration 969: Mean = 0.0295  StdDev = 1.2995  t = 2.2580  p = 0.0120
#
# Iteration 970: Mean = -0.0216  StdDev = 1.3229  t = -1.6237  p = 0.9478
#
# Iteration 971: Mean = -0.0161  StdDev = 1.2792  t = -1.2517  p = 0.8947
#
# Iteration 972: Mean = -0.0132  StdDev = 1.2755  t = -1.0318  p = 0.8489
#
# Iteration 973: Mean = 0.0576  StdDev = 1.3029  t = 4.4067  p = 0.0000
#
# Iteration 974: Mean = 0.0089  StdDev = 1.2759  t = 0.6953  p = 0.2434
#
# Iteration 975: Mean = 0.0534  StdDev = 1.2629  t = 4.2150  p = 0.0000
#
# Iteration 976: Mean = 0.0081  StdDev = 1.2906  t = 0.6232  p = 0.2666
#
# Iteration 977: Mean = 0.0217  StdDev = 1.2889  t = 1.6768  p = 0.0468
#
# Iteration 978: Mean = 0.0805  StdDev = 1.3060  t = 6.1440  p = 0.0000
#
# Iteration 979: Mean = 0.0186  StdDev = 1.2641  t = 1.4662  p = 0.0713
#
# Iteration 980: Mean = 0.0070  StdDev = 1.2953  t = 0.5390  p = 0.2949
#
# Iteration 981: Mean = -0.0058  StdDev = 1.3001  t = -0.4475  p = 0.6727
#
# Iteration 982: Mean = -0.0093  StdDev = 1.2794  t = -0.7218  p = 0.7648
#
# Iteration 983: Mean = -0.0032  StdDev = 1.2851  t = -0.2508  p = 0.5990
#
# Iteration 984: Mean = 0.0115  StdDev = 1.2979  t = 0.8852  p = 0.1880
#
# Iteration 985: Mean = 0.0255  StdDev = 1.2871  t = 1.9743  p = 0.0242
#
# Iteration 986: Mean = 0.0130  StdDev = 1.3043  t = 0.9946  p = 0.1600
#
# Iteration 987: Mean = -0.0342  StdDev = 1.3210  t = -2.5804  p = 0.9951
#
# Iteration 988: Mean = 0.0005  StdDev = 1.2876  t = 0.0387  p = 0.4845
#
# Iteration 989: Mean = 0.0105  StdDev = 1.2903  t = 0.8121  p = 0.2084
#
# Iteration 990: Mean = 0.0260  StdDev = 1.2361  t = 2.0951  p = 0.0181
#
# Iteration 991: Mean = 0.0153  StdDev = 1.3119  t = 1.1611  p = 0.1228
#
# Iteration 992: Mean = -0.0010  StdDev = 1.3085  t = -0.0777  p = 0.5310
#
# Iteration 993: Mean = 0.0488  StdDev = 1.2806  t = 3.7965  p = 0.0001
#
# Iteration 994: Mean = 0.0131  StdDev = 1.2650  t = 1.0282  p = 0.1519
#
# Iteration 995: Mean = -0.0342  StdDev = 1.2999  t = -2.6203  p = 0.9956
#
# Iteration 996: Mean = 0.0261  StdDev = 1.2813  t = 2.0277  p = 0.0213
#
# Iteration 997: Mean = -0.0248  StdDev = 1.2722  t = -1.9406  p = 0.9738
#
# Iteration 998: Mean = -0.0198  StdDev = 1.3134  t = -1.5029  p = 0.9336
#
# Iteration 999: Mean = 0.0590  StdDev = 1.2833  t = 4.5839  p = 0.0000
#
# Iteration 1000: Mean = -0.0282  StdDev = 1.2685  t = -2.2165  p = 0.9867
#
# Iteration 1001: Mean = 0.0109  StdDev = 1.2702  t = 0.8567  p = 0.1958
#
# n OOS = 9926  Median t = 0.5733  Fraction with p<= 0.1 = 0.360
# {'n_OOS': 9926,
#  'median_t': 0.5733346175010996,
#  'fraction': 0.3596403596403596,
#  't_scores': array([-0.07620695,  1.4837993 ,  2.0990322 , ...,  4.58394381,
#         -2.2164894 ,  0.85669788])}
